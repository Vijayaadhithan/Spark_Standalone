# %%
import pandas as pd 
import sys
import h5py
import numpy as np
import tables as HDF5

# %%
import glob
files = glob.glob('/content/drive/MyDrive/MillionSongSubset/*/*/*/*.h5')

# %%
len(files)
# Out:
# 10000

# %%
filter(lambda x: x[:3] == 'get',HDF5.__dict__.keys())

# %%
# %time
artist_names = []
artist_familiarity = []
artist_hotttnesss = []
artist_id = []
artist_latitude = []
artist_longitude = []
artist_location = []
song_id = []

for f in files:
    
    h5 = h5py.File(f, 'r')
    
    artist_name = h5['metadata']['songs']['artist_name'][0].decode('utf-8')
    artist_familiar = h5['metadata']['songs']['artist_familiarity'][0]
    artist_hot = h5['metadata']['songs']['artist_hotttnesss'][0]
    artist_ids = h5['metadata']['songs']['artist_id'][0]
    artist_lat = h5['metadata']['songs']['artist_latitude'][0]
    artist_long = h5['metadata']['songs']['artist_longitude'][0]
    artist_loc = h5['metadata']['songs']['artist_location'][0].decode('utf-8')
    song_idss = h5['metadata']['songs']['song_id'][0].decode('utf-8')
    
    artist_names.append(artist_name)
    artist_familiarity.append(artist_familiar)
    artist_hotttnesss.append(artist_hot)
    artist_id.append(artist_ids)
    artist_latitude.append(artist_lat)
    artist_longitude.append(artist_long)
    artist_location.append(artist_loc)
    song_id.append(song_idss)
    
    h5.close()
# Out:
# CPU times: user 8 µs, sys: 1e+03 ns, total: 9 µs
# Wall time: 12.9 µs

# %%
data_artist = {'song_id':song_id
        ,'artist_names':artist_names
        ,'artist_familiarty':artist_familiarity
        ,'artist_hotness':artist_hotttnesss
        ,'artist_latitude':artist_latitude
        ,'artist_longitude':artist_longitude
        ,'artist_location':artist_location
        ,'artist_id':artist_id
       }

# %%
artist_df=pd.DataFrame(data_artist)

# %%
len(artist_df)
# Out:
# 10000

# %%
artist_df.head()
# Out:
#               song_id   artist_names  artist_familiarty  artist_hotness  \
# 0  SOBQAPA12A8C13261C  Basement Jaxx           0.803619        0.531213
# 1  SOYIWNY12AC3DF96FC       Lady Saw           0.680620        0.440326
# 2  SOAMUDI12A6D4FCD11   Coco Montoya           0.576452        0.420007
# 3  SOHKQXL12A8C1379B9         Virtue           0.564594        0.310069
# 4  SOCYJTH12AB0184649         Franco           0.600487        0.453270
#
#    artist_latitude  artist_longitude      artist_location  \
# 0              NaN               NaN      London, England
# 1              NaN               NaN  St. Mary's, Jamaica
# 2         34.01156        -118.49229     Santa Monica, CA
# 3              NaN               NaN
# 4              NaN               NaN     Sona-Bata, Zaire
#
#                artist_id
# 0  b'ARFSPOV1187B9B2363'
# 1  b'ART5IUL1187B9B0143'
# 2  b'ARKBCZ91187B98F486'
# 3  b'ARO3PIY1187B989933'
# 4  b'ARPHH7Z1187B9B6A3A'

# %%
song_id = []
song_titles =[]
song_durations =[]
song_release_years =[]
song_hotness  =[]
track_id =[]
# %time
for f in files:
    
    h5 = h5py.File(f, 'r')
    
    song_idss = h5['metadata']['songs']['song_id'][0].decode('utf-8')
    song_title = h5['metadata']['songs']['title'][0]
    song_duration = h5['analysis']['songs']['duration'][0]
    song_release_year = h5['musicbrainz']['songs']['year'][0]
    song_hot = h5['metadata']['songs']['song_hotttnesss'][0]
    track_idss = h5['analysis']['songs']['track_id'][0]
    
    song_id.append(song_idss)
    song_titles.append(song_title)
    song_durations.append(song_duration)
    song_release_years.append(song_release_year)
    song_hotness.append(song_hot)
    track_id.append(track_idss)
    
    h5.close()
# Out:
# CPU times: user 14 µs, sys: 1e+03 ns, total: 15 µs
# Wall time: 20.5 µs

# %%
data_song = {'song_id':song_id
        ,'track_id':track_id
        ,'song_titles':song_titles
        ,'song_durations':song_durations
        ,'song_release_years':song_release_year
        ,'song_hotness':song_hotness
       }

# %%
song_df=pd.DataFrame(data_song)

# %%
len(song_df)
# Out:
# 10000

# %%
song_df.head()
# Out:
#               song_id               track_id  \
# 0  SOBQAPA12A8C13261C  b'TRASIKP128F423EED7'
# 1  SOYIWNY12AC3DF96FC  b'TRASIWA12903CFFC4D'
# 2  SOAMUDI12A6D4FCD11  b'TRASIWH128F4234005'
# 3  SOHKQXL12A8C1379B9  b'TRASIDP128F428ECD1'
# 4  SOCYJTH12AB0184649  b'TRASITK128F92F346F'
#
#                                          song_titles  song_durations  \
# 0                                        b'La Photo'       240.01261
# 1                                     b'Get A Straw'       207.12444
# 2                            b'Gotta Mind To Travel'       233.48200
# 3                         b'Can You Hear The Angels'       223.05914
# 4  b'Die T\xc3\xbcr die zum Gl\xc3\xbcck f\xc3\xb...       220.47302
#
#    song_release_years  song_hotness
# 0                2007      0.360371
# 1                2007      0.215080
# 2                2007           NaN
# 3                2007      0.000000
# 4                2007      0.000000

# %%
song_tempo = []
song_bars =[]
song_beats = []
song_time_signatures =[]
song_tatum =[]
song_modes=[]
song_keys=[]
song_id = []

# %time
for f in files:
    
    h5 = h5py.File(f, 'r')
    
    song_speed = h5['analysis']['songs']['tempo'][0]
    song_bar = h5['analysis']['bars_start'][()]
    song_beat = h5['analysis']['beats_start'][()]
    song_time_signature = h5['analysis']['songs']['time_signature'][0]
    song_tat = h5['analysis']['tatums_start'][()]
    song_mode = h5['analysis']['songs']['mode'][0]
    song_key = h5['analysis']['songs']['key'][0]
    song_idss = h5['metadata']['songs']['song_id'][0].decode('utf-8')
    
    song_tempo.append(song_speed)
    song_bars.append(song_bar)
    song_beats.append(song_beat)
    song_time_signatures.append(song_time_signature)
    song_tatum.append(song_tat)
    song_modes.append(song_mode)
    song_keys.append(song_key)
    song_id.append(song_idss)
    
    h5.close()
# Out:
# CPU times: user 8 µs, sys: 1 µs, total: 9 µs
# Wall time: 11.7 µs

# %%
data_song_more = {'song_id':song_id
        ,'song_tempo':song_tempo
        ,'song_bars':song_bars
        ,'song_beats':song_beats
        ,'song_time_signatures':song_time_signatures
        ,'song_tatum':song_tatum
        ,'song_modes':song_modes
        ,'song_keys':song_keys
       }

# %%
song_more_df=pd.DataFrame(data_song_more)

# %%
len(song_more_df)
# Out:
# 10000

# %%
song_more_df.head()
# Out:
#               song_id     song_tempo  \
# 0  SOBQAPA12A8C13261C  Basement Jaxx
# 1  SOYIWNY12AC3DF96FC       Lady Saw
# 2  SOAMUDI12A6D4FCD11   Coco Montoya
# 3  SOHKQXL12A8C1379B9         Virtue
# 4  SOCYJTH12AB0184649         Franco
#
#                                            song_bars  song_beats  \
# 0  [2.52412, 3.95827, 5.25168, 6.59976, 8.0155, 9...     228.299
# 1  [1.65671, 4.11006, 6.69233, 9.44815, 12.23802,...     199.843
# 2  [0.51477, 2.06156, 3.65212, 5.19319, 6.73425, ...     226.888
# 3  [0.68725, 2.12971, 3.577, 5.02716, 6.50272, 7....     208.863
# 4  [0.755, 2.63233, 4.53314, 6.43356, 8.32338, 10...     220.473
#
#    song_time_signatures                                         song_tatum  \
# 0                     3  [1.81179, 2.05319, 2.29221, 2.52412, 2.75603, ...
# 1                     4  [0.26613, 0.54333, 0.82619, 1.10303, 1.37987, ...
# 2                     4  [0.13818, 0.51477, 0.89328, 1.27179, 1.65993, ...
# 3                     4  [0.14536, 0.32569, 0.50602, 0.68725, 0.86578, ...
# 4                     4  [0.30824, 0.53162, 0.755, 0.97957, 1.21704, 1....
#
#    song_modes  song_keys
# 0           0         11
# 1           1          7
# 2           0          2
# 3           1          0
# 4           0          4

# %%
all_song_df = song_df.merge(song_more_df, on='song_id')

# %%
len(all_song_df)
# Out:
# 10000

# %%
all_song_df.head()
# Out:
#               song_id               track_id  \
# 0  SOBQAPA12A8C13261C  b'TRASIKP128F423EED7'
# 1  SOYIWNY12AC3DF96FC  b'TRASIWA12903CFFC4D'
# 2  SOAMUDI12A6D4FCD11  b'TRASIWH128F4234005'
# 3  SOHKQXL12A8C1379B9  b'TRASIDP128F428ECD1'
# 4  SOCYJTH12AB0184649  b'TRASITK128F92F346F'
#
#                                          song_titles  song_durations  \
# 0                                        b'La Photo'       240.01261
# 1                                     b'Get A Straw'       207.12444
# 2                            b'Gotta Mind To Travel'       233.48200
# 3                         b'Can You Hear The Angels'       223.05914
# 4  b'Die T\xc3\xbcr die zum Gl\xc3\xbcck f\xc3\xb...       220.47302
#
#    song_release_years  song_hotness     song_tempo  \
# 0                2007      0.360371  Basement Jaxx
# 1                2007      0.215080       Lady Saw
# 2                2007           NaN   Coco Montoya
# 3                2007      0.000000         Virtue
# 4                2007      0.000000         Franco
#
#                                            song_bars  song_beats  \
# 0  [2.52412, 3.95827, 5.25168, 6.59976, 8.0155, 9...     228.299
# 1  [1.65671, 4.11006, 6.69233, 9.44815, 12.23802,...     199.843
# 2  [0.51477, 2.06156, 3.65212, 5.19319, 6.73425, ...     226.888
# 3  [0.68725, 2.12971, 3.577, 5.02716, 6.50272, 7....     208.863
# 4  [0.755, 2.63233, 4.53314, 6.43356, 8.32338, 10...     220.473
#
#    song_time_signatures                                         song_tatum  \
# 0                     3  [1.81179, 2.05319, 2.29221, 2.52412, 2.75603, ...
# 1                     4  [0.26613, 0.54333, 0.82619, 1.10303, 1.37987, ...
# 2                     4  [0.13818, 0.51477, 0.89328, 1.27179, 1.65993, ...
# 3                     4  [0.14536, 0.32569, 0.50602, 0.68725, 0.86578, ...
# 4                     4  [0.30824, 0.53162, 0.755, 0.97957, 1.21704, 1....
#
#    song_modes  song_keys
# 0           0         11
# 1           1          7
# 2           0          2
# 3           1          0
# 4           0          4

# %%
data = artist_df.merge(all_song_df, on='song_id')

# %%
len(data)
# Out:
# 10000

# %%
data.head()
# Out:
#               song_id   artist_names  artist_familiarty  artist_hotness  \
# 0  SOBQAPA12A8C13261C  Basement Jaxx           0.803619        0.531213
# 1  SOYIWNY12AC3DF96FC       Lady Saw           0.680620        0.440326
# 2  SOAMUDI12A6D4FCD11   Coco Montoya           0.576452        0.420007
# 3  SOHKQXL12A8C1379B9         Virtue           0.564594        0.310069
# 4  SOCYJTH12AB0184649         Franco           0.600487        0.453270
#
#    artist_latitude  artist_longitude      artist_location  \
# 0              NaN               NaN      London, England
# 1              NaN               NaN  St. Mary's, Jamaica
# 2         34.01156        -118.49229     Santa Monica, CA
# 3              NaN               NaN
# 4              NaN               NaN     Sona-Bata, Zaire
#
#                artist_id               track_id  \
# 0  b'ARFSPOV1187B9B2363'  b'TRASIKP128F423EED7'
# 1  b'ART5IUL1187B9B0143'  b'TRASIWA12903CFFC4D'
# 2  b'ARKBCZ91187B98F486'  b'TRASIWH128F4234005'
# 3  b'ARO3PIY1187B989933'  b'TRASIDP128F428ECD1'
# 4  b'ARPHH7Z1187B9B6A3A'  b'TRASITK128F92F346F'
#
#                                          song_titles  song_durations  \
# 0                                        b'La Photo'       240.01261
# 1                                     b'Get A Straw'       207.12444
# 2                            b'Gotta Mind To Travel'       233.48200
# 3                         b'Can You Hear The Angels'       223.05914
# 4  b'Die T\xc3\xbcr die zum Gl\xc3\xbcck f\xc3\xb...       220.47302
#
#    song_release_years  song_hotness     song_tempo  \
# 0                2007      0.360371  Basement Jaxx
# 1                2007      0.215080       Lady Saw
# 2                2007           NaN   Coco Montoya
# 3                2007      0.000000         Virtue
# 4                2007      0.000000         Franco
#
#                                            song_bars  song_beats  \
# 0  [2.52412, 3.95827, 5.25168, 6.59976, 8.0155, 9...     228.299
# 1  [1.65671, 4.11006, 6.69233, 9.44815, 12.23802,...     199.843
# 2  [0.51477, 2.06156, 3.65212, 5.19319, 6.73425, ...     226.888
# 3  [0.68725, 2.12971, 3.577, 5.02716, 6.50272, 7....     208.863
# 4  [0.755, 2.63233, 4.53314, 6.43356, 8.32338, 10...     220.473
#
#    song_time_signatures                                         song_tatum  \
# 0                     3  [1.81179, 2.05319, 2.29221, 2.52412, 2.75603, ...
# 1                     4  [0.26613, 0.54333, 0.82619, 1.10303, 1.37987, ...
# 2                     4  [0.13818, 0.51477, 0.89328, 1.27179, 1.65993, ...
# 3                     4  [0.14536, 0.32569, 0.50602, 0.68725, 0.86578, ...
# 4                     4  [0.30824, 0.53162, 0.755, 0.97957, 1.21704, 1....
#
#    song_modes  song_keys
# 0           0         11
# 1           1          7
# 2           0          2
# 3           1          0
# 4           0          4

# %% [markdown]
# # New section
