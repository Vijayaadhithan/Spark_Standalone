# %%
# import packages
import h5py
import time
import sys
import glob
import pyspark
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import desc

# %%
#Creating the Spark Session
spark = SparkSession.builder\
.master("spark://spark-master:7077") \
.appName("experiment")\
.config("spark.cores.max", 1) \
.config("spark.driver.memory",'1g') \
.getOrCreate()

sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/03/21 18:51:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Create Spark dataframe from h5df files:

# %%
# create Spark data frame 

start_time = time.perf_counter()

data_folder_path = '/opt/workspace/datascaleup/songs/*/*/*/*.h5'

#################################################
# read a dataset and return it as a Python list #

def f(path):
    with h5py.File(path,'r') as f:
        data = f['/metadata/songs']
        return [tuple(metadata if type(metadata)!= bytes else metadata.decode("utf-8")  for metadata in data[0].tolist())]
    
################################################

songs_hdf5_files_paths_rdd = sc.parallelize(list(glob.glob(data_folder_path)))

songs_metadata_rdd = songs_hdf5_files_paths_rdd.flatMap(f)
schema= ['analyzer_version', 'artist_7digitalid', 'artist_familiarity', 'artist_hotttnesss', 'artist_id', 
         'artist_latitude', 'artist_location', 'artist_longitude', 'artist_mbid', 'artist_name', 'artist_playmeid', 
         'genre', 'idx_artist_terms', 'idx_similar_artists', 'release', 'release_7digitalid', 
         'song_hotttnesss', 'song_id', 'title', 'track_7digitalid']

songs_metadata_df= songs_metadata_rdd.toDF(schema)

end_time = time.perf_counter()

print(f"Runtime: {end_time - start_time:.2f} seconds")
# Out:
# Runtime: 5.88 seconds

# %% [markdown]
# # Simple operation (rows count):

# %%
# return the number of songs

start_time = time.perf_counter()

songs_metadata_df.count()

end_time = time.perf_counter()
print(f"Runtime: {end_time - start_time:.2f} seconds")
# Out:
# [Stage 1:=============================>                             (1 + 1) / 2]
# Runtime: 19.95 seconds

# %% [markdown]
# # Complex operation (sort):

# %%
start_time = time.perf_counter()
unique_songs = songs_metadata_df.dropDuplicates(["title"])
songs_by_artist = unique_songs.filter(songs_metadata_df.song_hotttnesss.isNotNull()) \
    .groupBy("artist_name") \
    .agg({"song_hotttnesss": "max", "title": "collect_list"}) \
    .withColumnRenamed("max(song_hotttnesss)", "max_song_hotttnesss") \
    .withColumnRenamed("collect_list(title)", "sorted_songs") \
    .select("artist_name", "max_song_hotttnesss", "sorted_songs") \
    .orderBy(desc("max_song_hotttnesss"))

# Print the artists with all of their songs sorted by song hotness
for row in songs_by_artist.collect():
    artist_name = row["artist_name"]
    max_song_hotttnesss = row["max_song_hotttnesss"]
    sorted_songs = row["sorted_songs"]
    if max_song_hotttnesss is not None:
        print(f"{artist_name}:")
        for song in sorted_songs:
            print(f"    {song}")
            
end_time = time.perf_counter()
print(f"Runtime: {end_time - start_time:.2f} seconds")
# Out:
# (hed) p.e.:
#     A Soldiers Intro
# 1. Futurologischer Congress:
#     Die Art von Mann
#     La Excursion
#     Machinenfunk
#     Tokyo
# 2 Minutos:
#     Cancion De Amor
#     Como Caramelo De Limón
#     Rompan Todo
#     Tema De Adrian
#     Valentin Alsina
#     Vos No Confiaste
#     14 Botellas
#     1987
#     2 Minutos
# 2-4 Grooves feat. Reki D.:
#     Relax
# 2-Gether feat. Sarinah:
#     Feelin` Alone
# 20/20:
#     I Never Did No Hitler
#     It Goes On
#     So Many Reasons
# 23rd Turnoff:
#     Michaelangelo
# 2Fresh:
#     Get It Started
# 2raumwohnung:
#     Ja (Hanno's Poppersmonstermix)
#     Lachen und weinen
#     Mädchen mit Plan
#     Rette Mich Später (Michael Ilbert Radio Mix)
#     36 Grad (Paul van Dyk's Vandit Clubmix)
# 3 Doors Down:
#     Be Like That
#     Better Life
#     Duck And Run
#     Here Without You
#     It's Not Me
#     Sarah Yellin'
#     Who Are You
# 3 Steps Ahead:
#     My Mind Is Gone
# 3 of Hearts:
#     Is It Love
# 3OH!3:
#     CHOKECHAIN (Amended Album Version)
# 4 Skins:
#     A.C.A.B. (Bumper Sessions)
#     Bread Or Blood (Single)
#     Chaos (Live - Bridgehouse Tapes)
#     New War
# 4Him:
#     He Never Changes
#     Strange Way To Save The World
#     Wings
#     You Are Holy
# 50 Cent:
#     In Da House Skit
#     U Not Like Me
# 50 Cent / Mobb Deep:
#     Outta Control
# 5th Ward Boyz:
#     Ghetto Curse Words (Chopped&Screwed)
#     Ho Shit (Chopped&Screwed)
#     Studio Gangster
#     Undercover Gangstas
# 6CycleMind:
#     Across The Universe
#     Talkin' Bout A Revolution
# 99 Posse:
#     Rafaniello
#     Salario Garantito (Versione Strumentale)
# :Blacks On :Blondes:
#     Sublime Control
#     Superconstellation
# A-FS:
#     Get it Right
# A-Mei:
#     Intro
# A-Studio:
#     S.O.S.
# A.Z.:
#     Sosa (Explicit)
#     We Can't Win (Explicit)
# AFS:
#     Mother's Day Part 1
# AUDIO.3:
#     SPONT.AN
# Aaron Watson:
#     Rollercoaster Ride
#     Sweet Contradiction
#     Thats What I Like About a Country Song
#     Whiskey on the Fire
# Abbott & Chambers:
#     Never After
#     Where Are You
# Aberdeen:
#     Beyond the Light
# Abijah:
#     Children Of Love
# Abracadabra:
#     Otra vez
#     Te estoy saboreando
# Abraham Laboriel:
#     Exchange
#     Guidum
# Abrar - Ul - Haq:
#     Hello Hello
# Academy/Marriner:
#     Andante Cantabile (String Quartet No 1 In D Major
# Acorps de Rue:
#     Chanson Réaliste
# Ada Jane:
#     The Queen's Treatment
# Adam Ant:
#     Friend Or Foe
#     Goody Two Shoes
#     Manzenera
#     Mohair Locker Room Pin-Up Boys
#     Something Girls
# Adam Richmond:
#     Pic & Run
# Adr Lavey:
#     In The Name of the Father
# Aeoliah:
#     For Your Passion My Love
#     Inner Chamber
#     Temple Bells
#     The Passion (Regular)
#     We Are One Light
# Aerosmith:
#     Crazy
#     Cryin'
#     Janie's Got A Gun
#     Livin' On The Edge
#     Lord Of The Thighs
#     Milkcow Blues
#     Reefer Head Woman
#     Same Old Song And Dance
#     What It Takes
# Aesop Rock:
#     Coma
#     Flashflood
#     Limelighters (feat. Camp Lo) / Flunkadelic Interlude
#     N.Y. Electric / Hunter Interlude
#     No City - Instrumental
#     Train Buffer
# African Rhythm Messengers:
#     baby Wayo
# Aftermath:
#     9:2
# Agency 1.9.9.4:
#     Dayz Of Our Livez
#     Everyday Struggle (Bonus)
#     The Prayer - Feat. T.O. & Timberly K. Simmons
# Agnes:
#     I Need You Now
#     Non Conformist Acclaimed
# Ai Ai Ai:
#     Com Una Flama
# Aimable:
#     Tango Andorra
# Airto Moreira:
#     Hala_ Tumba And Timbal
# Akon:
#     Don't Matter
#     Gun Shot
#     Over The Edge
# Al Dexter:
#     I'll Wait for You Dear
# Al DiMeola:
#     God Bird Change
#     July
# Al Rapone:
#     Chere Duloone
# Alain Souchon:
#     J'veux Du Cuir (Live)
#     Le Bagad De Lann Bihoue
# Alain Turban:
#     L'Ardechoise Aux Cheveux Blanc
#     L'Homme au trapèze volant
#     Santa Monica (Version Originale 1980)
# Alain-François:
#     En silence
#     Minuit sur terre
#     Playa del sous-sol
#     The frog song
# Alan Feinberg:
#     Menuet in the Name of Haydn
# Alas:
#     Silencio De Aguas Profundas
# Albert Ayler:
#     Ghosts_ Second Variation
#     Music Is The Healing Force Of The Universe
# Albert King:
#     I'm Gonna Move To The Outskirts Of Town - Live
#     Please Come Back To Me - Live
#     Watermelon Man
# Albert Préjean:
#     Dede De Montmartre
#     Une java
# Alceu Valença:
#     Cintura Fina
#     Na Primeira Manhã
#     Sete Desejos
# Ale Möller:
#     Sandpolskan
# Alejandro Lerner:
#     Campeones De La Vida
#     Canta Una Canción De Amor
#     Nena Neurótica
#     No Hace Falta Que Lo Digas
#     No Me Acuerdo
#     Todo A Pulmón
# Aleks Syntek:
#     Doesn't Matter Where You Are (Intocable)
#     In My Arms (Live Auditorio Nacional 08)
#     Otra Parte De Mi (1997 Digital Remaster)
#     Sexo_ Pudor Y Lágrimas (Drum & Bass Mix)
#     Un Espacio Para Andar (2002 Digital Remaster)
# Alex:
#     Cumpagno 'e cella
#     Love Selecta (feat Iffectz & Marwa)
#     What If
# Alex Fong:
#     Hao Lai Hao Qu
# Alex Gopher:
#     Aurora (Rory's Cassette Jam Remix)
#     Keep on dancin' (Last man standin')
#     Song For Paul
# Alex Ubago:
#     Ciudad desierta
#     Temblando
#     20 horas de nada
# Alexandre Desplat:
#     Breaking In
#     Hidden Documents
#     High-Speed French Train
#     Le Chagrin de Coco
#     Meeting Daisy
#     Palmer enquête
#     The Epi-Pen
#     White Sand
# Alexisonfire:
#     Accept Crime (Album Version)
#     Mailbox Arson
# Alfredo Gutiérrez:
#     Dos Mujeres
#     El niño de la calle
#     El troyano
#     Linda mariposa
# Alfredo Kraus:
#     La Alegria Del Batallon
#     Los De Aragón: "Los De Aragón
# Alfredo Kraus - Orquesta de Conciertos de Madrid - Pablo Sorozábal:
#     El último romántico: romanza de tenor
# Alfredo Kraus/Paul Plishka/Matteo Manuguerra/Sherrill Milnes/Trinity Boys' Choir/Ambrosian Opera Chorus/National Philharmonic Orchestra/James Levine:
#     Caro! (Colline/Rodolfo/Schaunard/Children/Townspeople/Musetta) (1998 Digital Remaster)
# Alfredo Kraus/Tatiana Troyanos/London Philharmonic Orchestra/Michel Plasson:
#     Werther (1997 Digital Remaster)_ PREMIER ACTE/ACT ONE/ERSTES AKT: Mon âme a reconnu votre âme(Werther/Charlotte)
# Alice Cooper:
#     Caught In A Dream (Album Version)
#     Goin' To The River
#     Make That Money (Scrooge's Song) (Album Version)
#     This House Is Haunted
# Alice In Chains:
#     Angry Chair
#     God Smack
#     I Know Somethin (Bout You)
#     Lesson Learned
#     Sickman
#     Take Her Out
#     Would?
# Alicia Keys:
#     Heartburn
#     If I Ain't Got You
#     If I Was Your Woman
#     Karma
#     Wait Til You See My Smile
# Alkonost:
#     Dumy Moi-Zamicy Dal Nie...
# All Leather:
#     As The Hog Pisseth
#     Please Jesus_ Send Me Someone To Fuck
#     We're Skrewed (Otto Von Schirach My Supernatural Motorcycle Gang Will Knife U Open Piss & Shit All Over Your Organic Starbucks =iPhone Bank Account Lifeless Lifestyle Remix)
# Alternative TV:
#     Dub In Bed
#     Its Raining
#     Lemons_ For Kevin
#     Nasty Little Lonely
# Amalia Avgoustaki:
#     Dimitroula
# Amorphis:
#     And I Hear You Call
#     Crimson Wave
#     Into Hiding
#     Misery Path (From the Privilege of Evil)
#     Privilege of Evil (From the Privilege of Evil EP)
#     The Lost Name of God
# Amy Lambert:
#     Because He Loves Me
# Amy Winehouse:
#     In My Bed
#     Stronger Than Me
#     Valerie
# An Cafe:
#     KORITSU HOSPITAL
#     ONE WAY LOVE
#     Pipopapo Telpathy
#     Portraying Light With Rainbow Colored Crayon
#     S*B*Y
# Ana Bekuta:
#     Kako mi je pitas sad
# Ana Popovic:
#     Shadow After Dark
#     U Complete Me (Blues Version - Bonus Track)
# Anane:
#     Let's Get High (Yves Larock Radio Edit w Rap)
# Andrae Crouch:
#     Ive Got Confidence
#     Jesus Is the Lord
#     Praises
# Andraé Crouch & Solid Gospel:
#     My Tribute (to God Be The Glory)
# Andre Popp:
#     Fernando
# Andre Verchuren:
#     Tra-La-La Musette
#     Valse Des Montagnes
# Andreas Dorau:
#     Das Telefon sagt Du
#     Du Verstehst Mich Nicht
#     So Ist Das Nun Mal
#     So ist das nun mal
#     Warten
# André Blot:
#     Breiz Ma bro
# André Verchuren:
#     Aubade D'Oiseau
#     Aviatic
#     Jalousie
#     Poema
#     Un P'Tit Brin De Musette
#     Un Tout Petit Pantin
# Andréa:
#     It's Not Whatcha Got (Fondling Club Mix)
# Andy & Lucas:
#     Amores Cobardes
#     Dame Un Besito (Version Salsa)
#     Dime Si Me Quieres
#     Dios Bendiga
#     Hasta Los Huesos
#     Mirame A La Cara (Version Salsa)
#     Quiero Ser Tu Sueño
# Andy Andy:
#     La Culpa
#     Maldito Amor Featuring Tito El Bambino (Version Urbana)
#     Vida
# Andy Russell:
#     Easter Parade (1992 Digital Remaster)
#     I Love You And You Love Me
# Angela Dimitriou:
#     Den Mporo Na Figo
#     Edo Pou Ta Leme
#     Fotia Sta Savvatovrada (Live)
#     Ftei O Erotas
#     Mi Mas Agapas
#     Ta Methismena S' Agapo
#     To Pouli
# Angela Lashley:
#     Too Far From The Tree
# Angelica Maria:
#     Te Necesito
# Angelo Badalamenti / Keira Knightley:
#     Overture/Blue Tahitian Moon
# Angels:
#     Fifi
#     Tulip
# Angélica María:
#     Una Sopita De Tu Propio Chocolate
# Anita Kerr:
#     Over The Rainbow
# Ann Hampton Callaway;Laura Benanti;Michael Gruber;Everett Bradley:
#     Stompin' at the Savoy
# Ann Lee:
#     Hold the key
#     So deep
#     2 People
# Ann Nesby:
#     I'm Going All The Way (Album)
#     Tables Turn
# Anna Meliti:
#     Lefkes Selides
# Anne Dudley:
#     A Stepmother's Curse
#     Rachel's retribution
#     Still Lost in the Forest
#     Victims of the occupation
# Annie Lennox:
#     A Whiter Shade Of Pale
#     Erased
#     Little Bird
# Annie Minogue Band:
#     Love Goes Down (Part Deux)
# Anthony Blea Y Su Charanga:
#     Tumba Randy
# Anthony Watson:
#     I Love Being Single (club extended mix)
#     I'm Gonna Take My Time
# Antonio Bribiesca:
#     Anillo de compromiso
#     Una noche serena y obscura
# Antonio Koudele:
#     Once Upon A Time
#     TU MIRADA
#     Track BALLERINA GIRL
#     Track TAKE FIVE
# Antonis Remos:
#     Min Aporis
#     Min Tou Milate Tou Pediou
#     To Agalma
# Anubis Spire:
#     It Has Been A Long Time_ Hasn't It
# Apache Indian:
#     Badd Indian
#     Independent Girl (feat. Malki Singh)
#     Real People (Cybernetic Dub)
# Aphasia:
#     mixture of noize (part two: "walter sobchak" - live extract)
#     non-existent track (part one: "why don't you fuckin' remember anything ?")
#     sample processing failed (part one: "why don't you fuckin' remember anything ?")
# Architecture In Helsinki:
#     Heart it Races (Frank Tetaz Remix)
#     Heart it Races (Yacht's I Should Coco Mix)
#     Need To Shout
#     The Same Old Innocence
# Arco Iris:
#     Canción del Arco Iris
#     Felicidades
# Arctic Monkeys:
#     Dancing Shoes
#     Fake Tales Of San Francisco
#     From The Ritz To The Rubble
# Arctique:
#     Kyana
# Arkona:
#     Chiornie Debri Voini (The Black Abyss of War)
#     Epilogue
#     Skvoz' Tuman Vekov
#     Zalozniy
# Army of the Pharoahs:
#     Listen Up
#     Narrow Grave
# Arne Weise:
#     Sommarens sista mås
# Art Blakey's Jazz Messengers:
#     A Night in Tunisia
# Art Ensemble Of Chicago:
#     He Took A Cab To Neptune
#     Horn Webb
#     Sirius Calling
# Arthur Fiedler:
#     Doctrines
# Arthur Tracy:
#     A Sailboat In The Moonlight
#     Dance_ Gypsy_ Dance
#     Marta (Rambling Rose Of The Woods)
#     Red Sails In The Sunset
#     So Do I
#     Where Are You?
# Ashbrg:
#     Night Shift
# Ashes to Ashes:
#     Bury Me
#     Drive In Saturday - (Tribute to David Bowie)
#     Gemini
#     Mind On
#     Pass The Earplugs
# Asleep At The Wheel:
#     Big Balls And Cow Town
#     Hot Rod Lincoln
#     I Hate Christmas
#     Let Me Go Home Whiskey
#     The Letter That Johnny Walker Read
#     The Son Shines Down On Me
# Assassin:
#     Quarter P.O.D.
#     Str8 M.O.B.
# Astarte:
#     Oblivious Darkness
#     Risen From Within
#     Thorns of Charon (Pt. 2) - Emerge from Hades
#     Voyage to eternal Life
# Asterisk*:
#     Iron-head: Palestine
# Asure:
#     Ugly MF
# Aswad:
#     Ina Your Rights
#     Rudeboy
#     Your Recipe
# At All Cost:
#     Drugs
#     These Nest Five Years
# At The Gates:
#     City Of Screaming Statues
# Atari Teenage Riot:
#     Destroy 2000 Years Of Culture
#     Live At Brixton Academy 1999
#     Revolution Action
# Atman:
#     All Is One
#     Dancing With the Goddess (ttt rmx)
#     Distant Voices
#     Govinda
#     Lingan
#     Luminous Bliss
#     The Traveller
# Atomic Rooster:
#     Close Your Eyes
#     Little Bit of Inner Air
#     Living Underground
#     Stand By Me
#     Take It For Granted
#     The Rock
# Atreyu:
#     Blood Children (an Introduction) (Album Version)
#     Ex's And Oh's (Instrumental Version)
#     Gallows (Album Version)
#     Nevada's Grace (Album Version)
#     Shameful (LP Version)
#     The Remembrance Ballad (Album Version)
#     You Eclipsed By Me (Album Version)
# Audio Adrenaline:
#     Gloria (In The Name Of Love Album Version)
#     My God  (Audio Adrenaline Album Version)
#     Some Kind Of Zombie (Criscoteque Remix)
#     Will Not Fade  (Hit Parade Album Version (new Song))
# Aurlus Mabélé:
#     Frères de sang (feat. Meiway)
# Aurélien Merle:
#     C'est Dimanche
# Avril:
#     The Matter With You (Part I_ Ii_ Iii)
# Avril - Remix By Ana Rago:
#     The Date (Remix By Ana Rago)
# Avril Lavigne:
#     How Does It Feel
#     Innocence
#     Unwanted
# Axe:
#     Midnight  (LP Version)
# Ayo:
#     Complain
#     Down On My Knees
#     Girls
#     I Love You
#     Life Is Real
#     Only You
#     Watching You
#     Welcome Into My World
# Azukx:
#     Lift (Joi Blarneyformasian)
#     124 Stomp
# B.A.D.:
#     Chu Hsin
#     Interlude
# B.B. King:
#     Early In The Morning
#     Please Love Me
#     Please Remember Me
# Babbie Mason:
#     Isn't That Just Like God (Low Key Performance Track Without Background Vocals)
#     Isn't That Just Like God (Medium Key Performance Track Without Background Vocals)
#     Pray On
#     Who In the World (Album Version)
# Babe Ruth:
#     A Fistful Of Dollars (1994 Digital Remaster)
#     Dancer (2007 Digital Remaster)
# Baby Bash:
#     If Your Na Na Get Wet
# Baby Bash / Grimm:
#     Changed My Life
# Baby D:
#     Let Me Be Your Fantasy
# Baby Rasta & Gringo:
#     Avisame
#     Esto Es Real
#     Yo Quiero Contigo
# Backstreet Boys:
#     Larger Than Life
#     PDA
#     Shape Of My Heart
#     The Call
# Bad Brains:
#     At The Atlantis
#     At The Movies (1991 Digital Remaster)
#     At The Movies (Live)
#     Destroy Babylon
#     God Of Love (Album Version)
#     Riot Squad (1991 Digital Remaster)
# Bad Company:
#     Call On Me
#     Crazy Circles
#     Rock Steady
#     Simple Man
#     Valerie (LP Version)
# Bamberg Symphony Orchestra and Hans Swarowsky:
#     Hungarian Dances_ WoO 1: No. 12 in D Minor: Presto
# Bambino_ Ivan Tirado:
#     Amor Maldito
# Bandido:
#     End Of The Road (Head Hornys Remix)
# Barbara Fairchild:
#     Boulevard In Heaven
#     Comfort Creek
#     I'll Meet You In The Morning
#     Jezebel
#     The Other Side Of That Hill
# Barbara Jones:
#     Moonlight Lover
#     You Are Always On My Mind
# Barbarito Diez:
#     Bajo Un Palmar
#     De Paris Un Caballero
#     Flores Negras
#     La Sitiera
#     Sublime Ensoñacion
# Bare Jr.:
#     Naked Albino
#     Snippet 15
#     Tobacco Spit
# Barenaked Ladies:
#     This Is Where It Ends (Album Version)
# Barley Bree:
#     Flight Of Earls
# Baroness:
#     Grad
#     The Sweetest Curse
#     Wanderlust
# Barrabas:
#     Broadway Star
# Barry Goldberg:
#     Lost Love
# Barry Künzel:
#     Supervisor (Instrumental) (edition Tromo/Rückbank)
# Barry Manilow:
#     Come Monday
#     Say Goodbye
#     This One's For You
# Barry Manilow Featuring The Glenn Miller Orchestra with Debra Byrd:
#     Don't Sit Under The Apple Tree
# Basement Jaxx:
#     Feelings Gone (feat. Sam Sparro) (Joachim Garraud Remix)
#     Jump N Shout Featuring Slarta John (Radio Edit)
#     La Photo
#     Sfm
#     Twerk (feat. Yo Majesty)
# BassTurk:
#     Unutmam
# Be Bop Deluxe:
#     Between The Worlds
#     Music In Dreamland
#     Piece Of Mine
#     Sister Seagull (Live)
# Beastie Boys:
#     Crawlspace
#     Eugene's Lament
#     Flute Loop (2009 Digital Remaster)
#     Get It Together
#     Shadrach
#     Shadrach (2009 Digital Remaster)
# Beatnuts:
#     Monster For Music
#     No Escapin' This
# Beatnuts featuring Tony Touch:
#     Cocotaso featuring Tony Touch
# Beatnuts with Lil' Donny:
#     Spelling Beatnuts with Lil' Donny
# Beautiful Creatures:
#     Wish (Album Version)
# Beaver Harris:
#     Glo-Billy-Vee-Vee
# Bebo Norman:
#     Borrow Mine
#     Britney
#     Sunday
# Becky Baeling:
#     If You Love Me
# Bedrock:
#     Emerald
# Bedwetters:
#     Like A Deck Of Cards
# Beenie Man:
#     Bad Man Story
#     Cross The Bridge
#     Million Gal
#     Once a Year
#     Politrix
#     Stack and Pile
# Beenie Man Featuring Janet Jackson:
#     Feel It Boy (Deep Dish Danchall Remix) (Feat. Janet Jackson)
# Beenie Man Featuring Wyclef And Redman:
#     Love Me Now (Rockwilder Remix) (Feat. Wyclef And Redman)
# Behemoth:
#     Before The Æons Came
#     Chant For Eschaton 2000
#     Cursed Angel Of Doom (Previously Unreleased&Re-Recorded Track)
#     He Who Breeds Pestilence
#     Hello Space Boy
#     Here And Beyond
#     Malice
#     No Sympathy For Fools
# Bela Fleck And The Flecktones:
#     Frontiers (LP Version)
#     Michelle (LP Version)
#     Throwdown At The Hoedown (LP Version)
# Belami:
#     Te Miattad Változott Meg Az Életem
# Bellatrax feat. Tina Cousins:
#     Can't Hold Back
# Belle & Sebastian:
#     Stay Loose
# Belle and Sebastian:
#     I Could Be Dreaming
#     Like Dylan In The Movies
# Benabar:
#     Le Zoo De Vincennes
#     Porcelaine
# Benny Spellman:
#     I Didn't Know
# Beres Hammond Feat. Natural Black:
#     Let The Good Times Roll
# Bersuit Vergarabat:
#     Bolero Militar
#     Bolivian Surf
#     De Onda
#     Se Viene
#     Sencillamente
# Bert Kaempfert:
#     Cha Cha Brasilia
#     Don't Go
#     Happy Safari
#     Sugar Bush
# Bert Kaempfert And His Orchestra:
#     Games People Play
#     Just As Much As Ever
#     Let's Go Home
#     Talk
#     Wheeling Free
# Bescenta:
#     So In Love
# Bessie Smith:
#     Chicago Bound Blues
#     Cold In Hands Blues
#     Gin House Blues
# Beth Nielsen Chapman:
#     Fair Enough (LP Version)
# Betika_ Daouda:
#     C'est pas ma faute
# Beyoncé:
#     Be With You
#     Dangerously In Love Medley
#     Irreplaceable (Irreemplazable)
#     Krazy In Luv
#     Single Ladies (Put A Ring On It)
# Biddu:
#     Baat Ban Jaye
#     Raag Trance
# Big Daddy Kane:
#     Flame On
# Big Daddy Rick:
#     Pac's Break
# Big Jay Oakerson:
#     It's All In How You Look At It
# Big Mama Thornton with Kansas Bill and his Orchestra:
#     Hound Dog
# Big Maybelle:
#     New Kind Of Mambo
#     Tell Me Who
# Big Mike Griffin:
#     Sittin' Here With Nothing
#     The Last Thing I Need
# Big Mountain:
#     Where Do The Children Play? (LP Version)
# Big One:
#     Comfortubly Numb
# Big Rich:
#     Ballin' (Radio)
# Big Rich featuring Devo:
#     Taking Over
#     This Is How We Live: Northern Cali
# Big Rich featuring J. Stalin_ Aristotle:
#     Imaginary Gangsters
# Bill & Gloria Gaither:
#     Awesome God
#     Farther Along (Favorite Hymns Sung By The Homecoming Friends Album Version)
#     God Lead Us Along (Homecoming Hymns Version)
#     He Will Lead His Children Home
#     Holy Ground (Homecoming Hymns Version)
#     I Never Shall Forget That Day (Reunion Album Version)
#     I Walked Today Where Jesus Walked
#     I'll Meet You By The River (Southern Convention Songs Version)
#     Jesus Hold My Hand (The Best of Homecoming - Volume 1 Version)
#     Stand By Me (Freedom Band Album Version)
#     Til The Storm Passes By
# Bill Douglas:
#     Caroline
#     Highland
#     Infant Dreams
#     Karuna
#     Sapphire
# Bill Engvall:
#     Game Night (Album Version)
#     Getting Old Sucks (Album Version)
#     T-Ball and Indian Guides (LP Version)
#     15º Off Cool (Album Version)
# Bill Laswell:
#     Digitaria
#     Don't Lose Control
#     Slow Murder
#     The Gary Selchie - Solas
# Bill Murk:
#     Find us Faithful
#     I Will Call Upon the Lord
#     Morning Has Broken
#     What a Friend We Have in Jesus
# Billie Jo Spears:
#     Danny
#     It Makes No Difference Now
#     Lizzie And The Rain Man
#     Misty Blue
#     Permanently Lonely
#     What I've Got In Mind
#     '57 Chevrolet
# Billie Ray Martin Feat. Ann Peebles:
#     18 Carat Garbage
# Billy Butler:
#     I'm Gonna Make Her Mine - Original
#     She's Got Me Singing [Bonus Track]
# Billy Higgins:
#     Peace
# Billy Higgins_ Bob Berg_ Cedar Walton_ Tony Dumas:
#     Plexis
# Billy May & His Orchestra:
#     Fascinating Rhythm (Instrumental) (2007 Digital Remaster)
# Billy Murray:
#     Goodbye Broadway_ Hello France
# Billy Pilgrim:
#     Caroline (LP Version)
# Billy Walker:
#     Thank You For Calling
# Bimbo Band:
#     Oh ! Tannenbaum
# Bingo Players:
#     Get Up (Diplo Mix)
# Birdapres:
#     None Missing
# Birmingham Jubilee Singers:
#     Hope I'll Join That Band
#     King Jesus Is My Captain
#     Queen Street Rag (144826)
#     Rollin' Down To Jordan
#     Toot Toot Dixie Bound
# Bitty McLean:
#     Over The River
#     We´ve Only Just Begun
# Bizarre Inc:
#     Miracle
# Black Debbath:
#     Grønn Dame_ Rød Klut (Sangen Om Boken Om Damen Anne Enger Lahnstein)
#     The Four Big Ones (Essential Authors And Works)
#     Tredveårsfurua På Askøy
#     Ville Eyolf
#     Where To Piss And Shit In Oslo
# Black Eyed Peas:
#     Let's Get It Started
#     Tell Your Momma Come
# Black Eyed Peas / Les Nubians / Mos Def:
#     On My Own
# Black Flag:
#     Crass Commercialism
#     Jealous Again
#     Out Of This World
#     Police Story
#     Room 13
# Black Sheep:
#     Novakane
#     Novakane Groove
# Blind Blake:
#     Ain't Gonna Do That No More
#     Blake's Worried Blues
#     Bootleg Rum Dum Blues
#     Dry Bone Shuffle
#     Too Tight Blues No. 2
# Blind Boy Fuller:
#     Big Leg Woman Gets My Pay
#     Got To Find My Little Woman
#     Precious Lord
#     Put You Back In The Jail
# Blind Lemon Jefferson:
#     Gone Dead On You Blues
#     Got The Blues
#     Long Distance Moan
#     Long Lonesome Blues
#     Wartime Blues
# Blind Willie Johnson:
#     Church_ I'm Fully Saved Today
#     God Don't Never Change
#     If I Had My Way I'd Tear This Building Down
#     Jesus Is Coming Soon
#     John the Revelator
#     You'll Need Somebody On Your Bond
# Blind Willie McTell:
#     Boll Weevil
#     Let Me Play With Yo' YoYo
#     Love Makin' Mama (Take 2)
#     Writing Paper Blues
# Blindman's Sun:
#     The Fugitives
# Blingtones:
#     Baby U Acting Greezy (Ringtone_ Sonnerie)
#     Gross Throw-up Burp (Sonnerie_ Ringtone)
#     La boîte à hein biloute
#     Sonnerie lalaleulé hi houuu
#     South Side Rep Your Hood (Ringtone_ Sonnerie)
#     Stinky Breath
#     Torero
# Bloc Party:
#     One More Chance
#     Zephyrus
# Blondie:
#     Rapture (Us Disco Version) (1999 Digital Remaster)
# Blue Rodeo:
#     Fools Like You
#     Million Miles
#     Mystic River
#     Never Look Back
#     Up On That Cloud
# Bob Carlisle:
#     I Will Shelter You
#     Man Of No Reputation
#     Somewhere
#     Watched By An Angel
# Bob Cheevers:
#     Memphis Til' Monday
#     Under The Bayou Moon
# Bob Dylan:
#     New Pony
#     Simple Twist Of Fate
#     Trying To Get To Heaven
# Bob Hope:
#     Merry-Go-Runaround
# Bob Marley:
#     Corner Stone
#     Lively Up Yourself
#     Memphis
#     Small Axe
# Bob Marley & The Wailers:
#     Cry On (Acoustic Demo)
#     Rainbow Country (Red Gold And Green Version)
#     Smile Jamaica
#     Three Little Birds
# Bob Newhart:
#     General Chariot Corp. (LP Version)
#     Herb Philbrick - Counter Spy ( LP Version )
# Bob Sinclar:
#     Lala Song (Matesi DJ "Silverstatix"remix
# Bob Willis:
#     Ida Red
#     Sugar Blues
# Bob Wills:
#     Bubbles in My Beer
#     Linda Lou
#     Playboy Theme
#     Sittin' On Top of the Wolrd
#     South
#     Yearning Just For You
# Bobbie Gentry:
#     Ace Insurance Man
#     Courtyard
#     Miss Clara/Azusa Sue
#     Reunion
# Bobby Capo:
#     La Luna Enamora - Original
#     Piel Canela (Alternate Mix)
# Bobby Darin:
#     Bullmoose (LP Version)
#     Drown In My Own Tears (LP Version)
#     Hi De Ho
#     Intro. & Hello Young Lovers (Live) (2000 Digital Remaster)
#     Moritat (Mack The Knife)
#     Theme From "Come September" (LP Version)
#     (I Heard That) Lonesome Whistle
# Bobby Hutcherson:
#     Les Noirs Marchant (Rudy Van Gelder 24Bit Mastering) (2002 Digital Remaster)
#     Maiden Voyage (Rudy Van Gelder Edition) (2006 Digital Remaster)
#     Recorda-Me
# Bobby Marchan:
#     It Hurts Me To My Heart
# Bobby Pulido:
#     Alma De Metal
#     La Bruja Chafa
#     La Rosa
#     La Rosa (Live)
#     Mi Alma Esta Enamorada
#     Mi Corazón Y Mi Mente
# Bobby Russell:
#     Jingle Bell Rock
# Bobby Valentin:
#     Yo Soy Abacua
# Bobby Vee:
#     Anonymous Phone Call
#     I Wouldnt Change A Thing
#     The Story Of My Life
#     What To Do Crying Waiting Hoping Learning The Game
#     Wink Of An Eye
# Bomb Squad:
#     BOMB SQUAD
#     Flipside
#     Never Be (Bonus Track)
# Bombay Rockers:
#     Rock Tha Party
#     Wild Rose (Back 2 Basics Mix)
# Bon Jovi:
#     I Love This Town
#     Only Lonely
#     Raise Your Hands
#     The Distance
#     The Radio Saved My Life Tonight
#     This Ain't A Love Song
#     Till We Ain't Strangers Anymore
#     Wildflower
# Bon Jovi / Ray Davies:
#     Celluloid Heroes
# Bone Thugs-N-Harmony:
#     Fearless [Interlude] (Explicit Album Version)
#     Murder One
#     Servin' Tha Fiends
#     2 Glocks
# Bongzilla:
#     Champagne & Reefer
#     Cutdown
#     Stone a Pig
#     Witch Weed (Live)
#     666lb. Bongsession
# Bonita:
#     Dead End Sign
#     It Could Never Be You
# Bonita & Jerry Cormier:
#     Dans un grand mur
#     La maison ou j'ai grandi
#     Sans ton amour
# Boogie Pimps:
#     Get Back Down
#     Then Came You
# Boogie Pimps Feat. Steve Brookstein:
#     Promised Land
# Bounty Killer:
#     Ask Fi War
#     Cellular Phone
#     Coppershot
#     Gun Thirsty
# Bow Wow Wow:
#     C30 C60 C90 Go
#     Love_ Peace and Harmony
#     Sex
# Boyz II Men:
#     In My Life
#     Motownphilly
#     On Bended Knee
# Brainchoke:
#     Crystal Clear
#     Untitled
#     1st World Hypocrisy
# Brand X:
#     Collapsar
#     Hate Zone
#     Liquid Time (composition by John Goodsall)
#     Zero Db (drum solo by Frank Katz)
# Bravehearts:
#     Sensations
# Brazilian Tropical Orchestra:
#     Baby
#     Ho Capito Che Ti Amo
#     If You Leave Me Now
#     One Less Bell To Answer
#     Swan Lake
# Brenda Boykin:
#     Be My Lover
# Brenda Lee:
#     Against My Will (LP Version)
#     Ballin' the Jack
#     Everybody Loves Me But You
#     Having A Little Talk With Jesus
#     If I'M Dreaming just Let Me Dream
#     Your One And Only (LP Version)
# Brent Lamb:
#     All The Difference In The World
#     One About Heaven
# Brian Dullaghan:
#     And I Love You So
#     Can't Help Falling In Love
#     My First Day At School
#     The Wedding
# Brian Eno And David Byrne:
#     The Jezebel Spirit
# Brian Keane:
#     Battle Of The Rosebud / Cries
#     Dark Flashes
#     Time Is/Time Was
# Brian Tyler:
#     Festival Of Holi
#     I Dream Of Chi Chi
# Brice Kapel:
#     Aloha
#     Lo
# Brigada Victor Jara:
#     Parto em terras distantes
#     Parto em terras distantes (2.ª versão)
# Britney Spears:
#     Break The Ice
#     Can't Make You Love Me
#     Don't Go Knockin' On My Door
#     Everytime
#     My Prerogative
#     Oops!...I Did It Again
#     Someday (I Will Understand)
#     3
# Brixx:
#     7 Miles
# Broadcast:
#     Cool Kid
#     Downstream
#     Michael A Grammar
#     One Hour Empire
#     Where Youth And Laughter Go
# Bruce Katz Band:
#     Just An Expression
# Bruce Springsteen:
#     Rosalita (Come Out Tonight)
#     Working On The Highway
# Bruford:
#     Forever Until Sunday
# Bruisers:
#     Bloodshed
#     Never Fall
#     Police Opression
#     2 Fists Full Of Nothing
# Bruno Sanfilippo:
#     The Flight of the serpentarius
#     The Fourth Wish
# Bryan Ferry:
#     Don't Want To Know (1999 Digital Remaster)
#     Don't Worry Baby (1999 Digital Remaster)
#     Ja Nun Hons Pris
#     Slave To Love (7" Version) (2009 Digital Remaster)
#     Wildcat Days (1999 Digital Remaster)
#     2HB (1999 Digital Remaster)
# Bryan White:
#     God Gave Me You (Single/LP Version)
#     I Can't Wait 'Til Christmas (LP Version)
#     Love Happens Just Like That (LP Version)
# Bröderna Djup:
#     Ovanlär
#     Råskevärsrock
# Buckeye Politicians:
#     Ride On The Rhythm
# Buckwheat Zydeco:
#     Buck's Going Downtown (Album Version)
#     Hot Tamale Baby
#     Trouble (Studio)
# Buddy Johnson:
#     Because - Part 1
#     Did You See Jackie Robinson Hit That Ball?
# Buju Banton:
#     Destiny
#     Excerpt Of A Speech By Marcus Mosiah Garvey
# Bukka White:
#     Aberdeen Blues
#     Fixin' To Die Blues
#     My Baby
#     Single Man Blues
#     Sleepy Man Blues
# Bukue One:
#     Ready Now
#     Up Close and Personal
# Bullet For My Valentine:
#     Suffocating Under Words Of Sorrow (What Can I Do)
#     4 Words (To Choke Upon)
# Bumblefoot:
#     Abnormal (Acoustic)
#     Piranha
# Burt Bacharach:
#     Are You There (With Another Girl)
#     Love Theme (The Falling In Love)
# Busdriver:
#     Beauty Supply And Demand
#     Ellen Disingenuous
#     Sun Shower (Single Version)
#     Sun Shower - Cadence Weapon Remix (Cd)
#     Unemployed Black Astronaut
#     Unsafe Sextet/Gilded Hearts of Booklovers
#     (Bloody Paw On The) Kill Floor
# Busta Rhymes:
#     Genesis
#     Taste It
#     The Whole World Looking At Me (Explicit LP Version)
#     We Got What You Want
#     We Put It Down For Y'all (Explicit LP Version)
#     When Disaster Strikes (Explicit LP Version)
# Butterfly Temple:
#     Iskorosten' (instr.)
# Butthole Surfers:
#     All Day
#     Barking Dogs (From "Piouhgd")
#     Tongue
#     Ulcer Breakout
#     Wichita Cathedral [live]
#     22 Going On 23
# Buzzcocks:
#     Get On Our Own
#     No Reply (Demo)
#     Strange Thing
# Bézu:
#     Frou-frou
#     La bite du plombier
#     La java bleue
#     Le chacha des gorilles
#     Le clair de lune à maubeuge
#     Le rire du sergent
#     Le tortillard
#     Viens boire un petit coup à la maison
# Bülent Ceylan:
#     Bülent & Mompfreed: Mompfreedonium
#     Harald: Trinkhalleluja
# C-Side & Petit Mal:
#     Mudhump
# C.J. Chenier:
#     Banana Man
# C.L. Smooth:
#     Smoke In The Air (A Cappella)
# CMW - Compton's Most Wanted:
#     This Is A Gang
# Cachao:
#     Los Tres Glopes / The Three Beats (danza)
# Cache Cache:
#     Only Do for Love
# Cake:
#     Alpha Beta Parking Lot
#     Arco Arena
# Cal Tjader:
#     Along Comes Mary
#     Anyone Who Had A Heart
#     Manuel's Mambo
# California Oranges:
#     Feel Better
#     I Wont Let You Back In
#     Travel Writer
# Cam'Ron:
#     Bubble Music
#     Do Ya Thing (Remix) (Explicit Album Version)
#     I'm A Chicken Head (Skit)
#     I.B.S. (Amended Album Version)
#     O.T. (Skit)
# Cama:
#     Fade Away
#     In This Life
#     Walk With You
# Camp Lo:
#     Baby Mama
#     Black Connect 3
#     Bubblin' (Anita Demo)
#     Sparkle
#     Uptown
# Candlebox:
#     Breathe Me In
#     Lover Come Back To Me
# Candy Lo:
#     Ji Nian Pin
#     Ma Zui
#     Qu Ni De Hun Li
#     Si Lu
#     Suan Shu
# Canis Dirus:
#     A Somber Wind from a Distant Shore (Album)
# Cannon's Jug Stompers:
#     Heart Breakin' Blues
#     Mule Get Up In The Alley
# Cantara:
#     Ubi Caritas
# Capital Tax:
#     Givin' It Back
#     Slide In - Slide Out
# Capleton:
#     Bumbo Red
#     Conscience Ah Heng Dem (interlude)
#     Cry For Love
#     Raggy Road
#     Say Yeah
#     When Me A Move
# Captain Hollywood Project:
#     All I Want
#     Find Another Way
#     The Way Love Is
# Caramell:
#     Expolodera (som dynamit)
# Cardenales del Exito:
#     Lole Lolaila
# Cargo Cult:
#     Helium
# Carl Belew:
#     Am I That Easy To Forget
#     Love's Been Good To Me
# Carl Davis:
#     Cranford: Deborah's Vigil
#     Cranford: Holbrook
#     Resolutions from The Long Day Closes
# Carl Smith:
#     I Wonder Where You Are Tonight
#     If I Couldn't Hold Back The Dawn
#     If You Don't Somebody Else Will
#     Loose Talk
# Carlos Baute:
#     Angelito (Directo 09)
#     Estas hecha para mi (Directo 09)
#     Pobre diabla (Directo 09)
#     Te extraño porque te extraño
# Carlos Embales - Cutumba:
#     A una mamita
# Carlos Jimenez:
#     Anita Love's
# Carlos Nuñez:
#     Camiño De Santiago
#     Gabriel's Oboe (La Mision)
#     Quiero Ir Ao Mar
#     St Patrick's An Dro
#     A Costa De Galicia
# Carlos Ponce:
#     Decir Adios
#     Escuchame
#     Quiero
#     Todo Lo Que Soy
# Carman featuring Commissioned & The Christ Church Choir:
#     Let The Church Rise
#     The Same God
# Carmen Y Laura:
#     Destino Ingrato
#     Paloma Consentida
# Carroll Thompson:
#     Change
#     Show Some Love Where Is The Love feat. MackaB
# Cartel:
#     Fool
#     Georgia
# Casa Bulga:
#     Afraid Of Change (Tribal Vocal Mix)
# Casey Bill Weldon:
#     I'se Just A Bad Luck Man
#     New Round And Round
# Casiotone For The Painfully Alone:
#     Attic Room
#     Bad People
#     Dying Batteries
#     Happy Mother's Day
#     Nashville Parthenon
#     Rice Dream Girl
#     Town Topic (Instrumental)
#     White Jetta
# Caspa:
#     Back to '93
#     Power Shower
# Cassidy featuring R. Kelly:
#     Hotel
# Cassidy featuring Swizz Beatz:
#     I Get My Paper
# Cassie:
#     Long Way 2 Go (Album Version)
#     Long Way 2 Go [Friscia & Lamboy Club]
# Casual:
#     Bailando
#     Classic Material
#     I Didn't Mean To
#     I believe
#     Let Me
#     OAKtown
#     Precís
#     Turkey And Dressin
# Catherine Howe:
#     Freedom Enough (From Silent Mother Nature)
#     Going Home (Acoustic)
#     Where Would You Start? (From Harry)
# Catherine Howe & Vo Fletcher:
#     White Winter Hymnal
# Catherine King/Matthew Schwinghammer/The American Boychoir:
#     Trois Noëls québècois (trad): Gabriel
# Catia Werneck:
#     Himalaya Dreams
# Cedric Gervais Featuring Caroline:
#     Spirit in My Life (Earnshaw's Instrumental)
# Cedric Gervais feat. Second Sun:
#     Pills (Dub) (Dub)
# Cedric Myton:
#     Wisdom
# Cesar Camargo Mariano/Helio Delmiro:
#     Milagre Dos Peixes/ Musica Incidental: Cais/ Music Incidental: San Vicente
# Chalk Farm:
#     Lillie Anne
# Champion Jack Dupree:
#     Christina Christina Blues
#     One Scotch_ One Bourbon_ One Beer
#     Snaps Drinking Woman (LP Version)
#     When I Left Home
# Champion Jack Dupree With TS McPhee:
#     No Meat Blues
# Chantal Chamandy:
#     Zindegi
# Chaotica:
#     Hypergasm
#     Lobotomy
#     Turbocharger
# Charles Williams:
#     Barrage
#     Close Up
#     From the East
#     They Ride By Night
# Charles Williams And His Orchestra:
#     Portrait Of Clare (from 'Portrait Of Clare')
# Charley Patton:
#     Circle Round The Moon
#     Mississippi Boweavil Blues
#     Moon Going Down
# Charley Pride:
#     Help Me Make It Through the Night
#     Let The Chips Fall
#     (I'm So) Afraid Of Losing You Again
# Charlie Byrd:
#     Chim Chim Cheree
#     How Insensitive
#     It Don't Mean A Thing (If It Ain't Got That Swing)
#     Speak Low
# Charlie Byrd / Carlos Barbosa-Lima / Carlos Barbosa-Lima:
#     Sarambeque
# Charlie Byrd / Laurindo Almeida:
#     Choro II
# Charlie Byrd Trio:
#     Goody Goody
#     I've Got The World On A String
#     Travellin' On
# Charlie Cruz:
#     Si No Te Hubieras Ido
#     Si Te Dicen Por Ahi
# Charlie Khan:
#     Beautiful When You're Green
#     Cheshire Grin
# Charlie Louvin:
#     Don't Laugh
#     I'll Be Home When I Can
#     Just Between The Two Of Us
#     Love And Wealth
#     See The Big Man Cry
# Charlie McCoy:
#     Blue Yodel No. 1(T For Texas)
#     Columbus Stockade Blues
#     Night Life
# Charlie Patton:
#     34 Blues
# Charlie Peacock:
#     After Lovin You (Love Life Album Version)
#     Down in the Lowlands
#     Forgiveness (Love Life Album Version)
#     Hot Night Downtown
#     Night Won't Last Forever_ The (Kingdom Come Album Version)
#     Tears Falling Down
#     The Quality of Life
#     The Way Of Love (West Coast Diaries Vol. 1 Album Version)
# Charlie Rich:
#     Cold_ Cold Heart
#     Nice 'N' Easy
#     Only Me
#     You Don't Know Me
# Charlie Walker:
#     Pick Me Up On Your Way Down - Original
#     That Little Ole Wine Drinker Me - Original
# Charly García:
#     Asesíname
#     Bancate Ese Defecto
# Chatelaine:
#     Je me sens bien pasta fagioli
# Checkers:
#     Can't Find My Sadie
#     Don't Stop Dan
#     Oh Oh Oh Baby
# Chelsea:
#     Decide
#     Right To Work
#     Right to Work (Live)
# Cheo Feliciano:
#     Juguete
# Cheri Keaggy:
#     The Cross That Bears His Name
# Cherish The Ladies:
#     The Shaskeen / Gan Ainm
# Chet Atkins:
#     Bourrèe
#     Get Up & Go
#     Knucklebuster
# Chico:
#     Curvy Cola Bottle Body
#     Have U Own Things
# Chico Hamilton:
#     Autumn In New York
#     Denise
#     Denise (Jeremy Carlstedt Funk Variation)
# Chimaira:
#     Army Of Me (Album Version)
#     Left For Dead (Album Version)
#     Severed (demo) (Album Version)
#     The Flame
# Choir & Great Symphony Orchestra of the All-Union Radio_ N. Shpiller_ S. Krassovsky_ V. Gagarina & N:
#     Requiem Mass_ K. 626_ 1791: Agnus Dei (Larghetto) (Mozart)
# Chorus Line:
#     Mamma pettenami
# Chris Brown:
#     Famous Girl
#     Help Me
#     I Love U
#     I.Y.A.
#     So Glad
#     Talking Drum (Isea '95)
# Chris Eaton:
#     All Or Nothing
#     All Or Nothing  (Wonderful World Album Version)
# Chris Farlowe:
#     Blues As Blues Can Get
#     I Just Need Your Lovin' - Original
#     Paint It Black
#     Paperman_ Fly In The Sky - Original
#     What You Gonna Do - Original
# Chris Jagger:
#     Baby Is Blue
#     Still Waters
# Chris Rea:
#     Driving Home For Christmas
#     Josephine
#     Josephine (French Edit)
# Chris Rodriguez:
#     Saved (LP Version)
#     Turn Around (LP Version)
# Chris Standring:
#     Fat Tuesday
#     Mumbo Jumbo (jazz)
#     Say What!?!
#     Through the Looking Glass (jazz)
# Christian McBride:
#     D Shuffle Jam (Part 2)
# Christian Quast:
#     Jugglin' Clown
#     You Are!
# Christian adam:
#     Il a suffit d'une chanson d'amour
# Christie Hennessy:
#     Rick's Cafe
#     Roll Back The Clouds
#     The All-Ireland
# Christina Aguilera:
#     Beautiful
#     Cruz
#     Genio Atrapado
#     Pero Me Acuerdo De Tí
#     Walk Away
# Christophe Beck:
#     Main Title
#     Why Jack Called
# Christos Dantis:
#     Apisti
#     Den Pai Alo
#     Kenourgia Fotia
#     Pai Keros
#     24.000 Baci
# Christos Kedras:
#     Water Blazz (Chill House mix)
# Chucho Valdés:
#     Reprise: Tú mi delirio - Guajira - Si te contara - El manisero
# Citizen Kaned:
#     President Johnson
# City High:
#     Sista
#     The Only One I Trust
#     What Would You Do?
# Claire Elzière:
#     Au mariage des Levon-Lecu (Live)
#     Il fait déjà (Live)
#     Les frelons (Live)
# Claire Hamill:
#     Awaken - Lark Rise
#     Icicle Rain
#     If You'd Only Talk To Me (Bonus Track)
#     Japanese Lullaby
#     Sidney Gorgeous
#     To The Stars
#     24 Hours from Tulsa (Bonus Track)
# Clannad:
#     Cumha Eoghain Rua Ui Neill (Lament For Owen Roe)
# Clara Nunes:
#     Nação
#     Sofrimento De Quem Ama (1997 Digital Remaster)
#     Tudo E Ilusao (1997 Digital Remaster)
#     Zambele (1997 Digital Remaster)
# Clarence Gatemouth Brown:
#     Up Jumped The Devil - Live
# Clarence Profit:
#     Tropical Nights
# Clarisse Lavanant:
#     Beaux parleurs
#     Electron libre
# Claudio:
#     Simple Lullaby (Do Maj)
# Claw Hammer:
#     Brother Brick Says
#     Speak Softly
#     Succotash
#     Warm Spring Night
# Clementina De Jesus:
#     Itinerario
# Click / Click_ M_Ferri:
#     Beachport
# Cliff Bruner:
#     Milk Cow Blues
# Cliff Edwards/Disney Studio Chorus:
#     When You Wish Upon A Star
# Clifton Chenier:
#     Clifton's Two Step
#     It's Hard
#     Johnny Can't Dance
# Clp:
#     Insatiable (Instrumental Version)
#     Superconfidential
# CoCo Lee:
#     Each Time I Think Of You
#     Killing Me Softly With His Song
#     Mo Jing
#     Sunny Day
# Cockney Rejects:
#     Beginning Of The End
#     Big Time Charlie
#     Easy Life (Live)
#     It's Alright Bruv
#     Oi! Oi! Oi!
# Coco Montoya:
#     Gotta Mind To Travel
# ColdWorld:
#     Schmerzensschreie
# Columbia Symphony Orchestra;Igor Stravinsky:
#     The Firebird/Apparition de L'Oiseau de Feu_ poursuivi par Ivan Tsarévitch
# Commander Cody & His Lost Planet Airmen:
#     Sister Sue
# Commander Cody And His Lost Planet Airman:
#     Riot In Cell Block N.9
# Commander Cody And His Lost Planet Airmen:
#     Cajun Baby (LP Version)
#     Crying Time
#     Hawaii Blues (Album Version)
#     Riot In Cell Block #9
#     Too Much Fun
# Computer Paul:
#     Cuts (Bobby's Still In Williamsburg)
# Confetti's:
#     C Day (Maxi Club Version)
#     The Sound of C (Acapella)
# Conjunto Mar Azul:
#     Dime
#     Papel Quemado
# Connie Francis:
#     Baby's First Christmas
#     Embraceable You (LP Version from 'When The Boys Meet The Girls')
#     You Were Only Fooling
# Connie Smith:
#     Cincinnati Ohio
#     I'll Come Running
#     If I Talk To Him
#     Just One Time
# Controlled Dissonance:
#     All Purpose Experiment
# Conway Twitty:
#     Big Train
#     Sitting In A Dim Café
#     Slow Hand (LP Version)
# Cookies:
#     Believe In What I Say
#     Yan Chin
#     Yi Ji Ji Zhong
# Cool Connection:
#     I'm Your Boogie Man
# Cool cavemen:
#     Burlesque burglary
#     Everyone make love
# Coolio Da Unda Dogg:
#     Do Or Die
# Coph Nia:
#     Doppelgänger [Qliphothic Phantasmagoria]
# Corderoy:
#     Rock Guitar
# Corderoy & U4IC DJ'S:
#     3 Spirit
# Cornel Campbell:
#     Somebody Has Stolen My Girl
# Cornell Campbell:
#     Give Your Love To Me
#     Got To Tell The People
#     Just My Imagination
# Corona:
#     I Don't Wanna be A Star
#     I Gotta Keep Dancing
#     You Gotta Be Movin'
# Cotton Candy:
#     Hot Weiners (All The Way)
#     The Windsor Tap Recap
# Cowboy Mouth:
#     Disconnected
#     Jenny Says
#     My Little Blue One
# Cracker:
#     Dr. Bernice
#     My Life Is Totally Boring Without You
#     Shake Some Action
# Cradle Of Filth:
#     Summer Dying Fast
#     Sweetest Maleficia (Album Version)
# Crazy Girl:
#     Get Picked Up
#     Get Picked Up (Niyi Can't Mix Version 1)
# Creedence Clearwater Revived:
#     Have You Ever Seen The Rain
#     I Heard It Throught The Grapevine
# Crematorium:
#     A Disconsolate Winter Landscape
#     Dying Under A Binary Star
#     Unlearn
# Cristy Lane:
#     God Is The Answer (Footprints In The Sand Album Version)
#     It Came Upon A Midnight Clear
#     Making Up For Lost Time (Footprints In The Sand Album Version)
# Crystals:
#     He's A Rebel
# Cumberland Quartet:
#     One Day At A Time
# Curtis:
#     Not Going Back Again
#     Superstar Dog
#     The River
# Curtis Mayfield:
#     People Never Give Up
#     Soul Music (ReMastered)
#     Superfly (Single Mix Version)
#     This Year (ReMastered)
#     You Better Stop
# Cutting Edge:
#     She's Got A Brain (Leli / Zimmerman)
#     Slangen I Paradis
#     Tune In
# Cyndi Wang:
#     I'll Be Better
# Cyril Pahinui:
#     Mauna Loa (Vocal)
# Cândido:
#     Sentimentos Desiguais
# Céline Dion:
#     Because You Loved Me (Theme from "Up Close and Personal")
#     The Reason I Go On
#     Un Garcon Pas Comme Les Autres (Ziggy)
# D'Molls:
#     Father Time (Album Version)
# D.A.D.:
#     Girl Nation [Live]
#     Sleeping My Day Away [Live]
#     Wild Talk [Live]
# D.A.R.:
#     Que paso
#     Quiere Novio
# D.O.W.N.:
#     Freeword
#     Hustlin'
#     I Don't Give A F**K
#     I Don't Give a F**k
#     I Luv Dat Too
# D.R.S.:
#     Gangsta Lean (Gangstapella)
# D:Fuse:
#     Living The Dream
# D:Fuse vs The Scumfrog:
#     Stereo + Video
# DAVE MATTHEWS BAND:
#     The Space Between
#     Tripping Billies
# DCS:
#     Tu Hi Tu Sada
# DJ Clue / Fabolous Sport:
#     If They Want It
# DJ Deeon:
#     Dik N Ballz
#     Rubber Track
# DJ Dips:
#     Gerra De De
# DJ Envy:
#     Why Wouldn't I (featuring Fabolous & Paul Cain)
# DJ Godfather:
#     DJs Are The New Rockstars-Live Mashup Mix 7
#     From Da Back
#     Night on William Street
#     Where You From
# DJ Guy:
#     Freak it all Night
# DJ Harry:
#     Other Side of You
#     Shadows
#     Tragedy in Blue
#     'Round the Wheel
# DJ Icey:
#     A Little Louder
# DJ Isaac:
#     Focus
#     Hardcore From The Underland
#     The Hardway
# DJ Nasty:
#     Apologize
#     Buy You A Drink
#     Child Support
#     Do It
#     Houston Anthem
#     Pussy Hole
#     Shawty Get Loose
#     Sounds Of The City
#     Southern Fried
# DJ Omega:
#     E. Warren
#     Grown & Sexy
#     Pop dat shit
#     Shake That Thang
# DJ Ostkurve:
#     Sailing
# DJ Quik:
#     Born and Raised In Compton
#     Ladies And Thugs
#     Pacific Coast Remix
#     Pitch In OnA Party
# DJ Rashad:
#     Flame It Up
#     Juke Appeal
#     Juke It Down
# DJ Rashad featuring DJ Chi Boogie:
#     Hood Figga Juke
# DJ Slugo:
#     Bass To Bass
#     Designer Chick
#     Vulture 4
#     Where the Rats 3
#     Whip It
# DJ Spinn:
#     Bounce Back
#     Feelin You
#     Times Up
# DJ Spinn featuring Traxman:
#     Lil Mama Getdown
# DJ Taz:
#     C.O.G. To The ATL
# DJ X-Change:
#     Shawty Say
#     Zoned Out
# DJ X-Change featuring DJ Joey A:
#     Come Over
# DJ X-Change featuring DJ Omega:
#     At the Club
# DJ X-Change featuring Joey A:
#     Drop Low
# DMZ:
#     Don't Start Me Cryin' Now
#     He's Waitin'
# Daath:
#     Above Lucium (LP Version)
#     Cosmic Forge (LP Version)
#     From The Blind (LP Version)
# Dabbler:
#     When Your Ready
# Daddy Dog:
#     Bluesanova
# Dakis:
#     Kathe Mera Kathe Nihta (2005 Digital Remaster)
#     Min Xechnas (Forse)
#     Perasmena Mesanihta
#     Sentimento (Asteri_ Asteraki)
#     Tha Mino Pia Sto Parelthon (2005 Digital Remaster)
#     Tsai Me Lemoni (2005 Digital Remaster)
# Dale Russ / Finn MacGinty:
#     Hornpipes: The First of May / the New Century
#     Reels: Old Joes / the Cliffs of Moher / the clips of mohair / the slightly less-well-informed maid
# Dallas Holm:
#     Here We Are
#     A Broken Heart
# Dame Edna Everage with Carl Davis conducting the London Symphony Orchestra and The New Antipodean Singers:
#     Song Of Australia - Canto 6 (2009 Digital Remaster)
# Dame Joan Sutherland / New Philharmonia Orchestra / Richard Bonynge:
#     Joy To The World
# Damita:
#     Pray (Album Version)
# Damita Jo:
#     Face To Face
# Dan Cummins:
#     Chocolate Squirrelador (Album Version)
#     Jiggle Once And Wait (Album Version)
# Dan Moretti:
#     Dreams - Original
# Dan Shen_ Gruppo Vocale Cantemus_ Ensemble Airone_ Luigi Marzola:
#     Miserere: IV. Quoniam Iniquitatem
#     Miserere: XI. Cor Mundum
#     Miserere: XII. Ne Projicias
#     Miserere: XVII. Quoniam Si Voluisses
# Daniel Chan:
#     Duo Liu Yi Hui
# Daniel Johnston:
#     Come To Me Tonight
#     Desperate Man Blues
#     Oh No
#     Rock Around The Christmas Tree
#     Story Of An Artist (Don't Be Scared)
#     The Story Of An Artist
#     To Go Home
#     Walking The Cow (Hi How Are You)
# Daniel Kobialka:
#     Singing The Night
#     Timeless Spirals
# Daniel Paul:
#     Coming Back For More feat. Colin Corvez
# Daniela Dessì:
#     Afro Profondo
#     New Age
#     Tramonto Etnico
# Danielle Bollinger:
#     Kiss the Sky
#     When the Broken Hearted Love Again
# Dann Huff:
#     Exception To The Rule
#     Light
# Danny Davis & The Boys:
#     The Golden Sea
# Danny Diablo feat. Puerto Rican Myke:
#     31 - 40
# Danny Elfman:
#     Birdies
#     Sleuthing
#     The Kingdom - Titles
# Danny Williams:
#     I Talk To The Trees
#     Stay Awhile
#     The Rainbow Bridge
#     The Wonderful World Of The Young
# Danny Wilson:
#     Get Happy
#     Never Gonna Be The Same
#     Spencer-Tracey
#     The Second Summer Of Love
# Daouda:
#     Mon coeur balance
# Darcelys:
#     Un Petit Cabanon Pas Plus Grand Qu'Un Mouchoir De Poche
# Darden Smith:
#     Frankie & Sue
#     Midnight Train
#     Mill Creek
#     Perfect Moment
# Dario Marianelli:
#     Falling Apart
#     The Harbour
#     The Lord's Prayer
#     Why Did You All Lie to Me?
# Dark Distant Spaces:
#     Remote Control
# Dark Fortress:
#     Evenfall
#     Ghastly Indoctrination
#     Incide
#     The Silver Gate
# Dark Shadows:
#     Carolyn & Barnabas
#     Departure / End Title (Love Theme From Night Of Dark Shadows)
#     Love Theme From Night Of Dark Shadows (unused Version)
#     The Taking Of Angelique
# Darko:
#     Danote
# Dart:
#     For The Good Times
# Daryl Coley:
#     He That Dwelleth (Psalm 91) (In My Dreams Album Version)
#     Standing On The Promises (Palmore) (Beyond The Veil Album Version)
# Daryl Hall & John Oates:
#     Everything Your Heart Desires
#     Only Love
#     Rich Girl
# Daughters:
#     Jones From Indiana
#     Pants_ Meet Shit
# Dave "Baby" Cortez:
#     The Happy Organ
# Dave Alvin:
#     All Night Worker
#     Somewhere In Time
# Dave Graney & Clare Moore:
#     You Put a Spell on Me
# Dave Hollister:
#     Bad When U Broke
#     Calm Da Seas
#     I Know I Can
#     I'm Wrong
#     One Woman Man
#     Tell Me Why
# Dave Rave_ Mark McCarron:
#     Face
#     They Held Hands
# David & Steve Gordon:
#     East Wind Drum Call
#     Evenglow
#     Faithkeeper_ Part 1
#     Yoga de Sensualite
# David Andreu:
#     El Sabor lo Pongo Yo
# David Banner:
#     Bush
#     Syrup Sipping (Banner Beat Break)
# David Bowie:
#     Baal's Hymn
#     Moss Garden (1999 Digital Remaster)
#     Space Oddity (1997 Digital Remaster)
#     Time Will Crawl (Extended Dance Mix)
# David Evans:
#     Now Is A Needy Time
#     Prison Bound Blues
#     Skinny Woman (Gravel Road Woman)
# David Gilmour Featuring Richard Wright:
#     Arnold Layne
# David Hudson:
#     Arrival
#     Didgeralia
#     Kurrajong
#     Monkey & Turtle
# David Jalbert:
#     Nocturne For Piano No. 5 In B Flat Major_ Op. 37
#     Nocturne For Piano No. 8 In D Flat Major_ Op. 84 No. 8 (also in Huit pièces brèves_ Op. 84/8)
#     North American Ballads: No. 2 - Which Side Are You On?
# David Lynch:
#     Carry The Light
#     Lit'l(er) Song
#     Unicorn
# David Palmer:
#     Émergences: III. Fragments d'épaves
# David Raksin:
#     The Bad And The Beautiful
# David Rose:
#     Wear Your Love Like Heaven / Workin' On A Groovy Thing (Medley) (1997 Digital Remaster)
# David Saylor:
#     Big World
#     Que Ves Por Tu Ventana
#     This Time
#     Ven a Mi
# David Summers:
#     Las Murallas De Jericó
#     Tu Mejor Amigo
#     2.000 Kilometros
# David Tao:
#     Everything's Gone
#     Love Can
#     Summer Love Triangle
#     Susan Said
#     Total Vision
# David Taylor:
#     Concertino for Bass Trombone and Trombone Choir
# David Zinman:
#     Des Helden Widersacher
# David Zinman;Pittsburgh Symphony Orchestra:
#     Concerto for Orchestra (Zoroastrian Riddles) (1996)/3. Adagio non troppo
# Dax Riggs:
#     Didn't Know Yet What I'd Know When I Was Bleedin'
#     Night is the Notion
#     Ouroboros
#     Radiation Blues
# Daylight Torn:
#     Sebastian
# Daywind Studio Musicians:
#     I Must Tell Somebody
# DeGarmo & Key:
#     Destined To Win
#     Don't Stop The Music (Streetlight Album Version)
#     He Has Risen (Communication Album Version)
#     Jericho  (Straight On Album Version)
#     Out Of The Danger Zone (Degarmo And Key Album Version)
# Dead Kennedys:
#     Halloween
# ...
#     Guarda Che Luna
# Bobby "Blue" Bland:
#     You Hit The Nail On The Head
# Bobby Bland:
#     Drifting From Town To Town
# Bone Loc:
#     King Bong
# Boney James And Rick Braun:
#     Shake It Up (Album Version)
# Bowen_ Robin Huw:
#     All Through The Night (Album)
# Bravehearts featuring Nas and Jully Black:
#     Situations
# Brownie McGhee:
#     Tell Me Baby
# Bruce Carroll:
#     The Room
# Bug Mafia:
#     Poezie De Strada / Street Poetry
# Bullethole:
#     Now I Know
# Caballo Dorado:
#     Me vuelves loco
# Cadet:
#     Medley: Father_ I Adore You/More Precious Than Silver
# Carl Doy with NZSO:
#     The First Noel
# Carlos Jimenez_ J Elvira_ Oliversam:
#     La vida (Jp Candela & Vlada Asanin club mix)
# Carlton Livingston:
#     Slow Down
# Cauda Pavonis:
#     Juggernaut
# Chanta Vielma:
#     Rio Grnade
# Chapta_ Stage McCloud_ SupaStarr & Tony Manshino:
#     Get F#%ked Up
# Charanga Forever:
#     Tumba Tumba
# Cherrelle:
#     Into My Eyes
# Chico Hamilton Quintet:
#     Skinned Strings
# Chops:
#     Give It To 'Em
# Chris Camozzi:
#     Sunday In Marin
# Ciaran Byrne:
#     Signs Can Hear All
# Clarence Fountain:
#     Beams Of Heaven
# Clockwise:
#     the tales of King Solitude 1:3
# Coffinberry:
#     Welcome To Hell
# Commissioned:
#     I'm Gonna Let My Love Flow
#     You Can Always Come Home
# Cookie Crew:
#     Got To Keep On (12" Version)
# Coraleena Ellis:
#     Wide Awake In A Dream
# Corey / Shaquille O'Neal:
#     MVP
# Criminal Class USA is Hush Hush Revolution:
#     Many Weapons Many Men
# Crusaders:
#     She's My Woman
# DJ Phiene:
#     Bass Fanactiks
#     Thump Thump Da Box
# DJ Primo:
#     Give It All You Got
# DJ Spinn and DJ Rashad:
#     Like It's Hot
# Dale Hawkins:
#     Pretty Little Thing
#     Wish I Hadn't Called Home
# Damone:
#     Child Of The Night
# Dan Hicks:
#     He Don't Care (He's Stoned)
# Danilo Perez / Claus Ogerman:
#     The Saga Of Rita Joe
# Daryl Coley Featuring the New Generation Singers Reunion Choir:
#     I Will Bless Your Name
# David Johansen:
#     In Style
# David Martin:
#     It Must Be
#     It Wont Be Christmas
# David Mingyue Liang:
#     Youlan_ Lonely Orchid (solo guqin)
# David Phelps:
#     One King (Album Version)
# David Rose & His Orchestra:
#     One Love
# Davol:
#     Another Land (World)
#     Champion (World)
# Defari:
#     Xtra Thump (Featuring Tash from Tha Alkaholiks)
# Dells:
#     Why Do You Have to Go
# Dezz White:
#     Drunk Driving Tip
# Diego Vasallo:
#     Dos imposibles
# Doug Sahm:
#     Sometimes (LP Version)
# Doug Sahm Tex Mex Trip:
#     Catch Me In The Morning (Album Version)
# Drexel:
#     Blood On The Snow
# Drouz:
#     Turn Me Around
# Drowning Pool:
#     Reborn (Explicit)
# East To West:
#     As Long As I Know
# Ebru Yasar:
#     Birak Yakami
# Ed Bruce:
#     Ruby Don't Take Your Love To Town
# Ed Calle:
#     Bar Talk
# Eden's Bridge:
#     By My Spirit  ()
#     Just As I Am (Arr.)  (Different From Track One)
#     Shout For Joy  (Celtic Psalms Album Version)
# Edith Lefel:
#     An ti chans'
#     L'a fête komine
# Eduardo Fernandez:
#     Estudio
# Elli Kokkinou:
#     Sex (French Version)
# Elton Britt:
#     Little Silver Bells
# Elvira:
#     Momentum
# Emile Vacher:
#     Plaisance-Fox
# Emit:
#     Gum
# Ernest Ranglin / Floyd Lloyd:
#     Sweet Lady
# Extasick:
#     Misanthrope
# Eyes Cream:
#     Open Up Your Mind (Guido Osorio Club Mix)
# F.l.y.:
#     Shit 3 Outro
# FIR:
#     Lydia [Piano Version]
# Faking David:
#     Down A Notch
#     Sex Will Sell
# Far Too Jones:
#     Use Me
# Farlow-Kirch Band:
#     Juke Joint
# Faye Adams:
#     Crazy Mixed Up World
#     My Greatest Desire
# Florida Boys:
#     Mansion in the Sky
# Flávio José:
#     Jogo Limpo
#     É Sempre Assim
# Francky Vincent:
#     L'antillais Donne
#     Ma Garçonniére
# Frank Vignola:
#     But Not For Me
# Frankie Howard:
#     Three Little Fishes
# Freakhouse:
#     Submit
# Frenchy:
#     Baby_ It's Gonna Cost You
#     Smith & Wesson
# Fulanito:
#     Lado A Lado (Bomba Carnaval Mix)
# Gabriel Grossi:
#     Cai dentro
#     Rebuliço
# Geoff Muldaur:
#     Tennessee Blues (Album Version)
# George Schuller:
#     Distant Cousin
# Ghorwane:
#     Matarlatanta
#     Nudez
# Giuseppi Logan:
#     Bop Moon
# Go Fish:
#     I Believe In You (More Than A Story Album Version)
# Grand Funk:
#     Please Me (24-Bit Digitally Remastered 02)
# Greater Vision:
#     Carol Of The Bells (Instramental Featuring The Budapest Pops Orchestra)
#     Everyone_ Everywhere_ Everytime
#     Heaven's Hero (Featuring Champion Of Love)
#     I Was Blind But Now I See
# Greek Gypsy Musicians:
#     Teska (Teska)
# Groupa:
#     Bliv Du Till Gran (If You Became A Spruce)
# Gruppo Jazz Marca:
#     Sensazioni a_b & c
# Guy Forsyth:
#     When I Think About Love
# Hal Russell:
#     For Free
# Hard Romantic:
#     Romanza
#     Sincerely_
# Harry Connick_ Jr:
#     Joe Avery's Piece
# Herbst9_ Z'ev:
#     Awakening of the Soulless
#     Reinvigorated (Maschinenkult_ Pt. 1)
# Hollywood Bowl Orchestra / John Mauceri:
#     John Dunbar Theme [Dances with Wolves]
# Hot Wire:
#     Like A Prayer (Tribute To Madonna)
# Human Disease:
#     Gold Flames Of Angels
# IYOV:
#     Hipster Haircut
#     I See War
# Ice-T & Chuck D:
#     Round Two Wrap-Up
# Indigenous:
#     Wanikaa (Featuring Abramz_ Krazy_ Lyrical G_ Saint Ca and Sylvester)
# Inner Circle:
#     Bed's Too Big Without You
# Irreversíveis:
#     Os Dois Irreversíveis
# Irtio:
#     Outubro
# Jacob Young:
#     In A Subtle Way
#     Print
# Jacques Ferchit:
#     Ça c'est Paris
# Jah Legacy:
#     What is the best
# James Blackwood with The Light Crust Doughboys:
#     This World Is Not My Home
# James Ingram:
#     A Baby's Born
# Jarvis Church:
#     So Beautiful
# Jauida:
#     I don't Want to Be Alone Tonight
# Javier Mendoza Band:
#     Rápido Nos Vamos
# Jean Gabin:
#     C'est moi le mari
# Jean-Claude Darnal:
#     Mélusine
# Jean-Jacques Goldman;Edith Lefel;Malavoi:
#     Chanson D'Amour
# Jessie Lee Miller:
#     All or Nothin' Gal
#     Hard To Admit
# Jill Paquette:
#     Sometimes Yes_ Sometimes No
# Jimmy Burns:
#     Groovin' With Jimmy
#     Rollin' And Tumblin'
# Jimmy Durante:
#     Amen (Album Version)
# Jinx:
#     Kutt Free (DJ Volume Remix)
# John Cephas & Phil Wiggins:
#     Twelve Gates To The City
# John Davis & Emma Doyle:
#     Mary's Boy Child
#     Rudolph The Red-Nosed Reindeer
# John Stewart:
#     Price Of The Fire
#     Wild Horse Road  (LP Version)
# Johnny Otis Show:
#     You Better Look Out
# Judy Mowatt:
#     Trade Winds
# Julio Iglesias Jr:
#     Angel
# Julissa:
#     Gloria
# Kalibas:
#     From Ivory Towers Above The Control Grid
# Karen Peck & New River:
#     Behind The Line Of Grace
# Kartik Seshadri:
#     Raga Anandi Kalyan (Alap_ jor and jhala)
# Kellie Coffey:
#     I Just Knew
# Kenny Price:
#     Biloxi
# Kommunity FK:
#     Junkies 1984
# Kostis Maraveyas:
#     Love Alone
# Kris Gruen:
#     Prayer Walk
# Kuldeep Paras:
#     Ek Pegh
# La Divina Pastora:
#     Instrumental Traditional
# Lacy J. Dalton:
#     Silver Bells
# Laura Leon:
#     Sicilienne (by Francis Poulenc)
# Le Vangle:
#     Ronde Lune
# Leaders Of The New School:
#     The End Is Near (LP Version)
#     Zearocks (LP Version)
# Leeroy Stagger:
#     House Of Sin
# Len Barry:
#     Dirty Old Man
# Leon Russel:
#     Three Bells / Les 3 cloches
# Leroy Van Dyke:
#     If A Woman Answers
# Les Witches:
#     Cupareree or Graysinn
# Little Angels:
#     The First Cut Is The Deepest
# Little Capes:
#     Like A Freza
# Little Joe & The Thrillers:
#     Peanuts
# Livio Minafra:
#     Campane
# Long John Hunter:
#     Slash
# Los Hispanos:
#     El Aranero
# Los Indios Tabajaras:
#     Sueño Salvaje
# Los Jaigüey:
#     Confiar Es Perder
# Los Morros Del Norte:
#     Raza Cristalera
# Los Ninos De Sara:
#     Espana tiene sabor
#     Lioraras
# Lou Reid & Carolina:
#     It's So Hard To Stumble (When You're Down On Your Knees)
# Louisa Mark feat. Kevin Henry:
#     Reunited
# Lunasicc:
#     Cheddar Chasin'
#     Pose No Threat
# Lynette Schultz:
#     Take Me Down To LA
# MIMS Featuring J. Holiday:
#     Be My Hustla (Explicit) (Feat. J. Holiday)
# Ma Rainey & Her Tub Jug Washboard Band:
#     Hear Me Talkin' To You
# Mademoiselle Sane:
#     Cabaret
#     La petite boite en fer
# Magnatune Compilation:
#     I Don't Care If You Lie (C Layne)
# Malina:
#     Druzya
#     Shagi po bitomu steklu
# Mandi:
#     Pieni Maailma
# Mar Azul:
#     Rancho Moreno
# Marc Dorsey:
#     Love You Again
# Marco Rima:
#     Der Kleine Idiot
# Marilyn Scott:
#     Take Me With You
# Mark Feldman_ John Taylor_ Anders Jormin_ Tom Rainey:
#     Everafter
# Mars Ill:
#     Saturday Night Special
# Martin Lawrence:
#     Talking During Sex (LP Version)
# Matteo Bonfanti e i maledetti:
#     Plaza de Mayo
# Meiway:
#     Aho
# Michael English:
#     Come On Home
# Michael Landau:
#     The Mighty SB
# Mick Hucknall:
#     I Love You More Than You'll Ever Know
# Mick Moloney:
#     Bodhrán Solo
#     Medley
# Mickey And The Students:
#     Gimme Gimme Song
# Midge Ure:
#     Four
# Midnight Fish:
#     Baby Here I Am
# Mike Jones:
#     Grandma (Screwed & Chopped Version)
# Mil:
#     Dis moi
# Milo:
#     Back Into Business
# Mirah:
#     Apples in the Trees (Live)
# Mocambo Allstars:
#     Brampton Boogaloo
# Monomonkey:
#     Where To Hide?
# Morton Gould:
#     Fall River Legend: Conversation: Morton Gould/Agnes de Mille
# Mr. Grillo:
#     Aqui Estoy
# Mr.De':
#     The Vine
#     Throw
# Mt. Wilson Repeater:
#     The Conversation
# Mum:
#     Mr. Crump
# Murphy Lee / Zee:
#     Murphy Lee
# Muzsikas:
#     Békási táncdallamok
# Mylon LeFevre:
#     Without Him (Ryman Gospel Reunion Version)
# Márcio Faraco:
#     Kanoê
# New York Dolls:
#     Don't Mess With Cupid (1972 demo)
#     Human Being (1972 demo)
#     Trash (live Paris)
# Nick Conolly:
#     Pseudoephedrine
# Nora:
#     The Power Of
# Norman Howard:
#     The Sound From There
# Norrie Paramor:
#     Dearly Beloved
# O'2L:
#     Little Edith
# Olga Tañon:
#     Ojos Negros
# Oliver Lake Quintet:
#     Only If You Live There
# Os Gaiteiros de Soutelo:
#     Estroupele-Troupele. Muiñeira
# Oscar Pettiford:
#     Judy's Jaunt
# Oui Oui:
#     La danse des petits amis
# Pale Forest:
#     Karma Violins
# Paris Musette:
#     Passion
# Paris_ Texas:
#     Hip Replacement
# Passion:
#     Jesus_ Lover Of My Soul (Bonus Stereo Trax)
# Patric C:
#     Everything Has Changed
#     Find The Office
# Patrick Lamb:
#     I Remember
# Patrick St-Eloi:
#     Anvi Viv?
# Paul Buckmaster:
#     Dunn's Revenge
#     The Interrogation
# Paul Overman:
#     Morning Rain Music by Jorge Alfano
# Paul Taylor / Terry Dexter:
#     Long Distance Relationship
# Perrocker:
#     Salsa pa tí
# Pete Bamboo:
#     Baila Cariño
# Pete Philly & Perquisite:
#     Eager (Live)
# Peter Spence:
#     Baby I
# Pietari Inkinen:
#     The Dryad_ Op. 45_ No. 1
# PitchBlack:
#     Satanic Majesty
# Plagia:
#     Floripa
# Population Reduction:
#     Road-Age at the Farmers Market
# Princess Lover:
#     Prends-Moi La Main
# Protein:
#     Karottensaft
# Rachael Lampa:
#     I'm All Yours (LP Version)
# Rainforest Trio:
#     Obsession
# Rakim:
#     Skit
# Randy Stonehill:
#     Angry Young Men (LP Version)
#     Can't Buy A Miracle - Album Version
#     Get Together - Album Version
# Raymond Lefèvre:
#     Générique - "le gendarme et les gendarmettes
# Red Stick Ramblers:
#     Why_ Now Baby?
# Refractory:
#     Check the bomb
# Rene Touzet:
#     Delirio
#     Mi Son Maracaibo
# Renee Rosnes:
#     Children's Song No. 3
#     Senegal Son
# Rhian Lois:
#     My Man's Gone Now
# Rhinostar:
#     Einfach
# Rincon Morales:
#     Gaita Gaitero
# Roberto Perera:
#     A Puro Dolor
# Roberto Roena:
#     Let It Rain
#     Oriza Eh
# Roberto Torres:
#     Decima Del Tiempo De Antes
#     Sabor Guajiro
# Robin Beanland:
#     Test Of The Terrarium
# Robin Frederick:
#     Calling Dr Zarkov
# Roger McGuinn:
#     The Bells Of Rhymney
# Roger Subirana:
#     Un Res Pyr
# Rory Block:
#     Blues Again
#     Three Is a Crowd
# Royal Bubble Orchestra:
#     Too Bad
# Rude Boys:
#     Heaven (LP Version)
# Rustless:
#     It's The Three Of Us Left
# Samba Mapangala and Orchestra Virunga:
#     Siri
# Samba Trio:
#     Essa Marie
# Sapo:
#     Eduardo
#     El Mes Alt
# Satan's Host:
#     Infernal Calling
#     Metal from Hell...22nd Century
# Serge Desaunay:
#     La polka des grenouilles
# Sex Machine:
#     We Wanna Change Our Band Name
# Shade Sheist / DJ Vice / DJ Echo / Damizza:
#     Holla Boyz Outro
# Shade Sheist / N.U.N.E. / King Arthur:
#     The Urban Gospel
# Shaman:
#     Battle Of The Tom Tom
#     For Tomorrow (live)
#     The Muddy Morning Hymn
# Shelley Fabares:
#     Johnny Loves Me (LP Version)
# Shout Out Out Out Out:
#     How Do I Maintain Pt. II
# Silvério Pessoa:
#     Eu vi a maquina voadora
# Singing Melody Feat. Robyn:
#     Are You Home
# Sir Douglas Quintet:
#     She's About A Mover
# Slim Harpo:
#     I Love The Life I'm Living
# Small Facers:
#     Happiness Stan - Original
# Smartbomb:
#     Complicate It
# Smiley:
#     Come On Shake My Feelin'
# Sofi Marinova:
#     Studen plamuk
# Soul Mekanik:
#     Get Your Head Stuck On Your Neck
# Special Duties:
#     I Am The Curse (Duties Demo)
#     Punk Rocker '97
# Spieluhrmelodien:
#     Zeigt her eure Füße
# Stargarden:
#     Trybal
# Stars Like Fleas:
#     You Are My Memoir
# State of Chaos:
#     CHAOS INTRO
# Stern:
#     Tüflische Plan
# Steve Porter:
#     Mindless
# Steve Wilson:
#     Your God Isn't Listening
# Sulk:
#     Only You (Chimi-Changa Club Mix)
# Supertalented:
#     Fax Me
# Susana Seivane:
#     Mazurcas das Rías Baixas
#     Para Milladoiro
#     Xoanina
# Sven Scholander:
#     Melangtäras intåg i Kallsta
# T.G.Sheppard:
#     When I Fall In Love
# Tammy Pescatelli:
#     Playboy Foundation
# Taya wooden:
#     Mothers Rastas
# Ten Wheel Drive:
#     No Next Time
# Terry Dexter:
#     Beautiful One
# The Antripodean Collective:
#     The Very Conscious
# The Bureau De Change:
#     Seasick
# The Chico Hamilton Quintet:
#     Night Beat
# The Chieftains;Colin James:
#     Cúnla/The Friar's Breeches
# The Cutting Edge:
#     Cutting Edge
# The Family Stand:
#     The Education Of Jamie
# The Fever:
#     Bye Bye Betty Blue
# The Firesign Theatre:
#     We Heart Billville (LP Version)
# The Fontane Sisters:
#     Seventeen (Digitally Remastered)
#     The Tennessee Waltz
# The Gaskets:
#     Deportees
# The Honeydogs:
#     Kandiyohi
# The Insects:
#     Winds of Change
# The Jason Bonham Band:
#     Bing
# The John Buzon Trio:
#     I Can't Believe That You're In Love With Me (Digitally Remastered 95)
# The Katinas:
#     One More Time (Kennedy Center Homecoming Version)
# The Keys:
#     From Tense To Loose To Slack
# The Mighty Clouds Of Joy:
#     I've Come This Far by Faith
# The Mustangs:
#     Moscow Nights
# The Nightraver & The Magican:
#     Drop the Bass
# The Oak Ridge Boys:
#     God's Hands
# The Skabs:
#     Woe is Woman
# The Stolen Minks:
#     I Hate You
#     Your Broken Heart
# The Unborn Chikken Voices:
#     Again And Again
# The Wilburns:
#     Keep Walking
#     One Little Baby
# The Wiyos:
#     Dontchaletmecatchya
# This Moment In Black History:
#     Blackwords Masking
# Thrilla U:
#     I Love You Baby
# Théophil:
#     Anti fashion victime
#     De belles
#     Madame Irma
# Tina Britt:
#     He Put The Hurt On Me
# Tito Rodriguez_ Louie Ramirez:
#     La Piel de Tu Alma
# Toby Love Feat. Girlz Talk:
#     Yo Quiero Saber
# Tony Murena:
#     Mambo Italiano
# Tresenlesen:
#     Das Gelübde
#     Rülpsen Sie Eine Hauptstadt
# Tri Atma:
#     RAMUKA
# Triana Pura:
#     Afonsina y el mar
#     Con el chacacha del tren (Cancíon por Rumba)
# Trick Trick / Eminem:
#     Welcome 2 Detroit
# Twinkle Twinkle Little Rock Star:
#     Jamming
# UKW:
#     Allein
#     Einmal reich
#     I Will (Patitu)
# Undertakin' Daddies:
#     Pictou County Coal
#     Two Wheels In the Ditch
# V Sinizter:
#     Valentine's Day
# Vana:
#     Village Dance
# Vicious Mary:
#     Keysage
# Vienna Concert House Orchestra_ Wiener Sängerknaben_ Ferdinand Grossmann:
#     Requiem Mass in D Minor_ K. 626: VIII. Lacrimosa dies illae
# Vilma Palma:
#     Lluvia De Acido
# Vince Taylor:
#     Sweet Little Sixteen
# Vincenzo:
#     Valium
# Vincenzo Bellini:
#     Bellini: Norma: Vanne_ e li cela entrambi
# Virtue:
#     Can You Hear The Angels
# Vorstadtkinder:
#     Los!
# Vulgar Pigeons:
#     O.R.P.
# Walter Jackson; Arranged & conducted by Riley Hampton:
#     Moonlight In Vermont
# Way Out West:
#     Banzai Washout
# We Five:
#     Milkcow Blues (Album Version)
# Weirdos_ The:
#     I Want What I Want
# Wendy Moten:
#     Make This Love Last
# Wilmington Chester Mass Choir:
#     Lord You're Worthy (Album)
# Winston McAnuff_ The Bazbaz Orchestra:
#     Common sense
# Winterlight:
#     Daybreak
# X-Raided featuring Teddy Bear_ Big Pook_ T-Nutty:
#     Thug Love
# Ya Boy:
#     How U Want It?
# Year of Desolation:
#     L.S.M.
#     The Legend of Yellow Boobie
# Yuko Kanzaki:
#     Seikurabe (Karaoke)
# ZTrip:
#     Addison Faceplant
# Zachary Richard:
#     See You Later Alligator
# Zeltinger Band:
#     Wo bleibt die Mark?
# Zen Lemonade:
#     Brazil Mon Amour
# lextrical:
#     Synthetic Dream
# liquid soul & freq:
#     Liquid Frequencies (liquid Soul Mix)
# Runtime: 21.08 seconds

# %%
spark.stop()
